# %% [markdown]
# # Create folder template for new images

# %%
import pandas as pd

annotation_df = pd.read_csv("master_list.csv")
annotation_df.head()
# Out:
#                                             filepath  xmin  ymin  xmax  ymax  \
# 0  IMG_20230428_123528_jpg.rf.5687b7b914f6d9aa98c...   151    42   497   591
# 1  IMG_20230428_123522_jpg.rf.204ff37f497f2dce442...    88    81   442   567
# 2  IMG_20230428_123708_jpg.rf.141ecd0cefaea75c0b7...    35    34   492   622
# 3  IMG_20230428_123521_jpg.rf.1069b402272252862ec...    99   122   428   587
# 4  IMG_20230428_123659_jpg.rf.5e1b6c4caabe48cf360...   103    17   474   592
#
#                                 label ProductType    Weight HalalStatus  \
# 0  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 1  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 2  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 3  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 4  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
#
#   HealthStatus  new_camera  tag
# 0   NonHealthy           0  NaN
# 1   NonHealthy           0  NaN
# 2   NonHealthy           0  NaN
# 3   NonHealthy           0  NaN
# 4   NonHealthy           0  NaN

# %%
unique_labels = annotation_df["label"].unique()
unique_labels[:10]
# Out:
# array(['Sugar_400-499g_NonHalal_NonHealthy',
#        'OtherNoodles_700-799g_Halal_NonHealthy',
#        'OtherNoodles_400-499g_Halal_NonHealthy',
#        'Oil_500-599g_Halal_NonHealthy',
#        'BiscuitsCrackersCookies_200-299g_Halal_NonHealthy',
#        'BiscuitsCrackersCookies_100-199g_Halal_NonHealthy',
#        'Nuts_1-99g_NonHalal_NonHealthy',
#        'SweetsChocolatesOthers_1-99g_NonHalal_NonHealthy',
#        'HoneyOtherSpreads_300-399g_NonHalal_NonHealthy',
#        'OtherNoodles_400-499g_NonHalal_NonHealthy'], dtype=object)

# %%
len(unique_labels)
# Out:
# 154

# %%
import os
import shutil

folder_path = os.path.join(os.getcwd(), "image_folder_template")

# Check if the folder exists
if os.path.exists(folder_path):
    # Remove the folder and its contents
    shutil.rmtree(folder_path)
    print(f"The folder {folder_path} has been deleted.")
else:
    print(f"The folder {folder_path} does not exist.")

for tmp_folder_name in unique_labels:
    tmp_folder_path = os.path.join(folder_path, tmp_folder_name)
    # The 'exist_ok' parameter is set to True, which means the directory won't be created if it exists
    os.makedirs(tmp_folder_path, exist_ok=True)
    
    # add .gitkeep file in each empty folder; otherwise it will not be uploaded in github
    # Create the .gitkeep file within the folder
    gitkeep_path = os.path.join(tmp_folder_path, ".gitkeep")
    # Create the .gitkeep file (it will be empty)
    with open(gitkeep_path, 'w'):
        pass
# Out:
# The folder /Users/liupeng/Documents/GitHub/object_detection_using_tensorflow/images_combined/image_folder_template has been deleted.

# %% [markdown]
# # Update master list (for existing training images)

# %%
import pandas as pd

annotation_df = pd.read_csv("master_list.csv")
unique_labels = annotation_df["label"].unique()
annotation_df.head()
# Out:
#    Unnamed: 0                                           filepath  xmin  ymin  \
# 0           0  IMG_20230428_123528_jpg.rf.5687b7b914f6d9aa98c...   151    42
# 1           1  IMG_20230428_123522_jpg.rf.204ff37f497f2dce442...    88    81
# 2           2  IMG_20230428_123708_jpg.rf.141ecd0cefaea75c0b7...    35    34
# 3           3  IMG_20230428_123521_jpg.rf.1069b402272252862ec...    99   122
# 4           4  IMG_20230428_123659_jpg.rf.5e1b6c4caabe48cf360...   103    17
#
#    xmax  ymax                               label ProductType    Weight  \
# 0   497   591  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g
# 1   442   567  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g
# 2   492   622  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g
# 3   428   587  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g
# 4   474   592  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g
#
#   HalalStatus HealthStatus  new_camera  tag
# 0    NonHalal   NonHealthy           0  NaN
# 1    NonHalal   NonHealthy           0  NaN
# 2    NonHalal   NonHealthy           0  NaN
# 3    NonHalal   NonHealthy           0  NaN
# 4    NonHalal   NonHealthy           0  NaN

# %%
import os

# Specify the directory you want to list
directory = '/Users/liupeng/Documents/new_camera_test'

# List all entries in the directory
entries = os.listdir(directory)

# Filter out entries that are directories
folder_names = [entry for entry in entries if os.path.isdir(os.path.join(directory, entry))]

print(folder_names)
# Out:
# ['WetWiper_100-199g_NonHalal_NonHealthy', 'CornChip_1-99g_NonHalal_NonHealthy', 'PotatoSticks_1-99g_Halal_NonHealthy', 'BiscuitsCrackersCookies_1-99g_Halal_NonHealthy', 'Book_1-99g_NonHalal_NonHealthy']

# %%
import os
from datetime import datetime

# Choose a date format
date_format = '%Y%m%d'  # This will give you a string like '20230123' for January 23, 2023
current_date = datetime.now().strftime(date_format)

# Rename each file in the directory
for tmp_folder_name in folder_names:
    tmp_folder = os.path.join(directory, tmp_folder_name)
    for filename in os.listdir(tmp_folder):
        old_file = os.path.join(tmp_folder, filename)
        if os.path.isfile(old_file):  # Check if it's a file, not a directory
            # Construct the new filename with the current date at the front
            new_filename = f"{current_date}_{filename}"
            new_file = os.path.join(tmp_folder, new_filename)

            # Rename the file
            os.rename(old_file, new_file)
            # print(f"Renamed '{old_file}' to '{new_file}'")
# Out:
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0121.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0121.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0135.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0135.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0135.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0135.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0121.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0121.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0136.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0136.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0122.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0122.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0122.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0122.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0136.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0136.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0133.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0133.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0127.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0127.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0127.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0127.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0133.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0133.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0132.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0132.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0126.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0126.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0126.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0126.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0132.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0132.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0124.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0124.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0124.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0124.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0131.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0131.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0131.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0131.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0142.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0142.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0156.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0156.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0156.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0156.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0142.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0142.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0157.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0157.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0157.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0157.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0155.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0155.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0155.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0155.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0140.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0140.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0140.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0140.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0150.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0150.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0144.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0144.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0144.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0144.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0150.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0150.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0153.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0153.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0153.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0153.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0146.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0146.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0152.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0152.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0152.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0152.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0146.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0146.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0163.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0163.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0163.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0163.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0162.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0162.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0162.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0162.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0160.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0160.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0160.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0160.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0161.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0161.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0149.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0149.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0149.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0149.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0161.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0161.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0159.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0159.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0159.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0159.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0158.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0158.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0158.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0158.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0128.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0128.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0128.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0128.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0129.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0129.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0129.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0129.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0139.png' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0139.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/output_frame_0139.xml' to '/Users/liupeng/Documents/new_camera_test/WetWiper_100-199g_NonHalal_NonHealthy/20231215_output_frame_0139.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0181.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0181.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0181.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0181.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0180.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0180.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0194.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0194.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0194.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0194.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0180.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0180.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0196.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0196.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0182.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0182.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0182.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0182.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0196.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0196.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0222.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0222.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0222.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0222.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0183.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0183.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0183.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0183.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0178.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0178.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0187.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0187.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0178.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0178.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0187.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0187.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0192.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0192.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0186.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0186.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0179.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0179.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0186.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0186.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0192.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0192.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0179.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0179.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0184.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0184.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0184.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0184.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0185.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0185.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0191.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0191.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0191.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0191.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0185.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0185.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0177.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0177.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0188.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0188.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0177.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0177.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0188.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0188.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0201.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0201.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0201.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0201.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0189.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0189.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0176.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0176.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0189.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0189.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0176.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0176.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0174.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0174.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0174.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0174.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0216.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0216.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0216.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0216.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0175.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0175.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0175.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0175.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0207.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0207.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0207.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0207.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0206.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0206.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0212.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0212.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0212.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0212.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0206.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0206.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0199.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0199.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0199.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0199.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0210.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0210.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0204.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0204.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0204.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0204.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0210.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0210.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0173.xml' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0173.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/output_frame_0173.png' to '/Users/liupeng/Documents/new_camera_test/CornChip_1-99g_NonHalal_NonHealthy/20231215_output_frame_0173.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0257.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0257.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0243.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0243.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0280.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0280.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0243.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0243.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0257.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0257.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0280.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0280.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0242.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0242.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0242.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0242.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0240.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0240.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0254.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0254.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0254.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0254.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0240.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0240.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0282.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0282.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0255.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0255.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0282.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0282.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0255.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0255.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0279.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0279.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0245.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0245.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0251.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0251.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0286.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0286.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0251.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0251.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0245.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0245.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0279.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0279.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0286.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0286.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0244.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0244.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0244.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0244.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0252.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0252.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0246.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0246.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0285.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0285.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0246.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0246.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0252.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0252.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0285.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0285.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0247.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0247.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0247.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0247.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0262.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0262.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0262.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0262.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0288.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0288.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0277.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0277.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0263.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0263.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0288.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0288.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0263.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0263.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0277.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0277.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0275.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0275.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0249.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0249.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0249.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0249.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0275.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0275.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0260.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0260.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0274.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0274.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0274.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0274.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0260.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0260.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0264.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0264.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0270.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0270.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0270.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0270.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0264.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0264.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0265.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0265.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0265.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0265.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0273.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0273.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0267.png' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0267.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0267.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0267.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/output_frame_0273.xml' to '/Users/liupeng/Documents/new_camera_test/PotatoSticks_1-99g_Halal_NonHealthy/20231215_output_frame_0273.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0069.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0069.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0082.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0082.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0069.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0069.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0082.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0082.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0083.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0083.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0068.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0068.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0083.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0083.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0068.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0068.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0108.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0108.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0108.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0108.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0056.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0056.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0056.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0056.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0094.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0094.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0080.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0080.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0080.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0080.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0094.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0094.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0090.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0090.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0090.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0090.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0091.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0091.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0091.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0091.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0078.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0078.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0087.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0087.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0078.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0078.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0087.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0087.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0074.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0074.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0074.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0074.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0061.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0061.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0075.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0075.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0075.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0075.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0061.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0061.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0101.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0101.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0101.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0101.png'
# ...
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0067.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0067.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0067.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0067.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0073.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0073.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0071.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0071.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0059.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0059.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0059.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0059.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0071.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0071.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0064.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0064.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0058.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0058.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0058.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0058.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0064.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0064.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0104.xml' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0104.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/output_frame_0104.png' to '/Users/liupeng/Documents/new_camera_test/BiscuitsCrackersCookies_1-99g_Halal_NonHealthy/20231215_output_frame_0104.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0041.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0041.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0041.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0041.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0043.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0043.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0043.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0043.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0046.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0046.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0046.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0046.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0045.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0045.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0045.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0045.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0023.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0023.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0037.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0037.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0037.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0037.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0023.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0023.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0009.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0009.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0035.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0035.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0021.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0021.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0021.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0021.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0035.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0035.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0009.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0009.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0030.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0030.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0024.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0024.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0018.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0018.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0018.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0018.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0024.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0024.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0030.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0030.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0031.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0031.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0025.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0025.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0019.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0019.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0019.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0019.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0025.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0025.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0031.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0031.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0027.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0027.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0033.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0033.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0033.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0033.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0027.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0027.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0026.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0026.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0026.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0026.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0003.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0003.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0017.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0017.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0017.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0017.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0003.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0003.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0002.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0002.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0016.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0016.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0016.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0016.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0002.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0002.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0014.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0014.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0014.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0014.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0029.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0029.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0015.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0015.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0015.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0015.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0029.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0029.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0005.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0005.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0039.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0039.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0039.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0039.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0005.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0005.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0010.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0010.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0010.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0010.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0007.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0007.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0013.png' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0013.png'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0013.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0013.xml'
# Renamed '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/output_frame_0007.xml' to '/Users/liupeng/Documents/new_camera_test/Book_1-99g_NonHalal_NonHealthy/20231215_output_frame_0007.xml'

# %%
import os
import xml.etree.ElementTree as ET
import shutil

for tmp_folder_name in folder_names:
    tmp_folder_path = os.path.join(directory, tmp_folder_name)
    # only look at folders with new images
    # if len(os.listdir(tmp_folder_path)) != 0:
    tmp_file_names = [f for f in os.listdir(tmp_folder_path) if f != '.gitkeep']
    if len(tmp_file_names) != 0:
        # loop through each file
        for tmp_file_name in tmp_file_names:
            # ignore xml file
            if not tmp_file_name.endswith('.xml'):
                # only add new images
                if tmp_file_name not in annotation_df['filepath']:
                    tmp_label = tmp_folder_name
                    tmp_folder_name = tmp_folder_name
                    tmp_ProductType = tmp_folder_name.split("_")[0]
                    tmp_Weight = tmp_folder_name.split("_")[1]
                    tmp_HalalStatus = tmp_folder_name.split("_")[2]
                    tmp_HealthStatus = tmp_folder_name.split("_")[3]
                    tmp_filepath = tmp_file_name
                    
                    tree = ET.parse(os.path.join(tmp_folder_path, tmp_file_name[:-4] + ".xml"))
                    # Get the root element
                    root = tree.getroot()
                    # Find the 'bndbox' element
                    bndbox = root.find('.//bndbox')
                    # Extract the coordinates
                    tmp_xmin = int(bndbox.find('xmin').text)
                    tmp_ymin = int(bndbox.find('ymin').text)
                    tmp_xmax = int(bndbox.find('xmax').text)
                    tmp_ymax = int(bndbox.find('ymax').text)
                    
                    new_row = {'filepath': tmp_filepath, 'xmin': tmp_xmin, 'ymin': tmp_ymin, 'xmax': tmp_xmax, 'ymax': tmp_ymax,
                              'label': tmp_label, 'ProductType': tmp_ProductType,
                              'Weight': tmp_Weight, 'HalalStatus': tmp_HalalStatus, 'HealthStatus': tmp_HealthStatus,
                              'new_camera': 1}
                    
                    annotation_df = pd.concat([annotation_df, pd.DataFrame([new_row])], ignore_index=True)
                    # annotation_df = pd.DataFrame([new_row])
                else:
                    print(tmp_file_name)
                    raise ValueError("Duplicate entry!")
        
        # Iterate over all files in the source folder
        destination_folder = os.path.join(os.getcwd(), "data_edit")
        for filename in os.listdir(tmp_folder_path):
            source = os.path.join(tmp_folder_path, filename)
            destination = os.path.join(destination_folder, filename)

            # Copy each file to the destination folder
            shutil.copy2(source, destination)

# %%
# import os
# import xml.etree.ElementTree as ET
# import shutil

# folder_path = os.path.join(os.getcwd(), "image_folder_template")

# for tmp_folder_name in folder_names:
#     tmp_folder_path = os.path.join(folder_path, tmp_folder_name)
#     # only look at folders with new images
#     # if len(os.listdir(tmp_folder_path)) != 0:
#     tmp_file_names = [f for f in os.listdir(tmp_folder_path) if f != '.gitkeep']
#     if len(tmp_file_names) != 0:
#         # loop through each file
#         for tmp_file_name in tmp_file_names:
#             # ignore xml file
#             if not tmp_file_name.endswith('.xml'):
#                 # only add new images
#                 if tmp_file_name not in annotation_df['filepath']:
#                     tmp_label = tmp_folder_name
#                     tmp_folder_name = tmp_folder_name
#                     tmp_ProductType = tmp_folder_name.split("_")[0]
#                     tmp_Weight = tmp_folder_name.split("_")[1]
#                     tmp_HalalStatus = tmp_folder_name.split("_")[2]
#                     tmp_HealthStatus = tmp_folder_name.split("_")[3]
#                     tmp_filepath = tmp_file_name
                    
#                     tree = ET.parse(os.path.join(tmp_folder_path, tmp_file_name[:-4] + ".xml"))
#                     # Get the root element
#                     root = tree.getroot()
#                     # Find the 'bndbox' element
#                     bndbox = root.find('.//bndbox')
#                     # Extract the coordinates
#                     tmp_xmin = int(bndbox.find('xmin').text)
#                     tmp_ymin = int(bndbox.find('ymin').text)
#                     tmp_xmax = int(bndbox.find('xmax').text)
#                     tmp_ymax = int(bndbox.find('ymax').text)
                    
#                     new_row = {'filepath': tmp_filepath, 'xmin': tmp_xmin, 'ymin': tmp_ymin, 'xmax': tmp_xmax, 'ymax': tmp_ymax,
#                               'label': tmp_label, 'ProductType': tmp_ProductType,
#                               'Weight': tmp_Weight, 'HalalStatus': tmp_HalalStatus, 'HealthStatus': tmp_HealthStatus,
#                               'new_camera': 1}
                    
#                     annotation_df = pd.concat([annotation_df, pd.DataFrame([new_row])], ignore_index=True)
#                 else:
#                     print(tmp_file_name)
#                     raise ValueError("Duplicate entry!")
        
#         # Iterate over all files in the source folder
#         destination_folder = os.path.join(os.getcwd(), "data_edit")
#         for filename in os.listdir(tmp_folder_path):
#             source = os.path.join(tmp_folder_path, filename)
#             destination = os.path.join(destination_folder, filename)

#             # Copy each file to the destination folder
#             shutil.copy2(source, destination)

# %%
annotation_df.to_csv("new_master_list.csv")

# %%
annotation_df.tail()
# Out:
#       Unnamed: 0               filepath  xmin  ymin  xmax  ymax  \
# 3152         NaN  output_frame_0039.png   524   172   924   738
# 3153         NaN  output_frame_0005.png   450   260   818   776
# 3154         NaN  output_frame_0010.png   420   245   856   858
# 3155         NaN  output_frame_0007.png   406   265   840   776
# 3156         NaN  output_frame_0013.png   422    46   899   601
#
#                                label ProductType Weight HalalStatus  \
# 3152  Book_1-99g_NonHalal_NonHealthy        Book  1-99g    NonHalal
# 3153  Book_1-99g_NonHalal_NonHealthy        Book  1-99g    NonHalal
# 3154  Book_1-99g_NonHalal_NonHealthy        Book  1-99g    NonHalal
# 3155  Book_1-99g_NonHalal_NonHealthy        Book  1-99g    NonHalal
# 3156  Book_1-99g_NonHalal_NonHealthy        Book  1-99g    NonHalal
#
#      HealthStatus  new_camera  tag
# 3152   NonHealthy           1  NaN
# 3153   NonHealthy           1  NaN
# 3154   NonHealthy           1  NaN
# 3155   NonHealthy           1  NaN
# 3156   NonHealthy           1  NaN

# %% [markdown]
# ### Rememeber to cleanse the image folder template after adding images by running the first section's codes

# %% [markdown]
# # To complete: create master list for new images

# %%
import cv2

frame = cv2.imread("data_edit/Photo on 9-11-23 at 4.33_PM #3.jpg")
# Out:
# [ WARN:0@660.500] global loadsave.cpp:244 findDecoder imread_('data_edit/Photo on 9-11-23 at 4.33_PM #3.jpg'): can't open/read file: check file path/integrity

# %%
1120-1032+212
# Out:
# 300
