# %% [markdown]
# <a href="https://colab.research.google.com/github/jackliu333/object_detection_using_tensorflow/blob/main/FoodBank_Training_Customised_Image_Detection_Model_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.9
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.9
#   Downloading tensorflow-2.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      |████████████████████████████████| 511.7 MB 3.7 kB/s
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (1.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (1.48.1)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 59.2 MB/s
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 37.7 MB/s
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (0.26.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (1.21.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (3.1.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (1.1.0)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 51.0 MB/s
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (1.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (21.3)
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (57.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (14.0.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (4.1.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9) (3.17.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow==2.9) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow==2.9) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (2022.6.15)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow==2.9) (3.0.9)
# Installing collected packages: tensorflow-estimator, tensorboard, keras, gast, flatbuffers, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0.7
#     Uninstalling flatbuffers-2.0.7:
#       Successfully uninstalled flatbuffers-2.0.7
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
#     Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220719082949
# Successfully installed flatbuffers-1.12 gast-0.4.0 keras-2.9.0 tensorboard-2.9.1 tensorflow-2.9.0 tensorflow-estimator-2.9.0
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following packages will be REMOVED:
#   libcudnn8-dev
# The following held packages will be changed:
#   libcudnn8
# The following packages will be upgraded:
#   libcudnn8
# 1 upgraded, 0 newly installed, 1 to remove and 18 not upgraded.
# Need to get 430 MB of archives.
# After this operation, 3,139 MB disk space will be freed.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcudnn8 8.1.0.77-1+cuda11.2 [430 MB]
# Fetched 430 MB in 17s (24.7 MB/s)
# (Reading database ... 155569 files and directories currently installed.)
# Removing libcudnn8-dev (8.0.5.39-1+cuda11.1) ...
# (Reading database ... 155547 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.1.0.77-1+cuda11.2_amd64.deb ...
# Unpacking libcudnn8 (8.1.0.77-1+cuda11.2) over (8.0.5.39-1+cuda11.1) ...
# Setting up libcudnn8 (8.1.0.77-1+cuda11.2) ...

# %%
# Codes adapted from https://github.com/nicknochnack/TFODCourse/blob/main/2.%20Training%20and%20Detection.ipynb
# Images sampled from https://github.com/jackliu333/object_detection_using_tensorflow, with bounding boxes drawn manually for each object
# To run using Google Colab; switch runtime type to GPU for speedup
import numpy as np
import random
import tensorflow as tf

SEED = 123
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# import tensorflow as tf
tf.version.VERSION
# Out:
# '2.9.0'

# %% [markdown]
# # Configuration parameters
#
# Including paths and training hyper-parameters

# %%
import os
print(f"Current OS: {os.name}")
# Out:
# Current OS: posix

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 

# SSD has good tradeoff between speed and accuracy; can switch to other pretrained model
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'

# TF official script to encode training data to tf record format
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'

# Mapping dictionary between label and integer id
LABEL_MAP_NAME = 'label_map.pbtxt'

# Define a list of folder paths to be created (if needed) and used later
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    # bounding box annotation
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
}

training_files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
# create folder paths if not exist
for p in paths.values():
    if not os.path.exists(p):
        # !mkdir -p {p}

# %% [markdown]
# # Set up TF model training logistics
#
# ### Download TF model training utility scripts from TF model zoo

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'objection_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow/models'...
# remote: Enumerating objects: 77288, done.
# remote: Counting objects: 100% (582/582), done.
# remote: Compressing objects: 100% (337/337), done.
# remote: Total 77288 (delta 284), reused 483 (delta 233), pack-reused 76706
# Receiving objects: 100% (77288/77288), 593.35 MiB | 24.32 MiB/s, done.
# Resolving deltas: 100% (54795/54795), done.

# %% [markdown]
# ### Install TF object detection library
#
# May hit some error during installation, can be ignored, as long as it returns "OK" in the last line.

# %%
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install .
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/Tensorflow/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.41.0-cp37-cp37m-manylinux2010_x86_64.whl (10.9 MB)
#      |████████████████████████████████| 10.9 MB 3.1 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.9.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.32)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 57.4 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.4)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.3.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.10.0-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 50.0 MB/s
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.27.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (25.0 MB)
#      |████████████████████████████████| 25.0 MB 9.2 MB/s
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.9.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.7 MB/s
# Collecting sacrebleu<=2.2.0
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      |████████████████████████████████| 116 kB 36.3 MB/s
# Collecting portalocker
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.21.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.6.2)
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 46.5 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.0 MB/s
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Collecting tensorflow~=2.10.0
#   Downloading tensorflow-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      |████████████████████████████████| 578.0 MB 15 kB/s
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 8.4 MB/s
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.6.0)
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 41.9 MB/s
# Collecting opencv-python-headless==4.5.2.52
#   Downloading opencv_python_headless-4.5.2.52-cp37-cp37m-manylinux2014_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 61.9 MB/s
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.11)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 56.3 MB/s
# Collecting tensorflow-text~=2.10.0
#   Downloading tensorflow_text-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 22.0 MB/s
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Collecting immutabledict
#   Downloading immutabledict-2.2.1-py3-none-any.whl (4.0 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 45.8 MB/s
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.31.6)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.35.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.17.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2022.2.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.6.15)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.48.1)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.0-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 48.5 MB/s
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.6)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 52.5 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.26.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Collecting keras
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 40.1 MB/s
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 62.6 MB/s
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Collecting orjson<4.0
#   Downloading orjson-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (270 kB)
#      |████████████████████████████████| 270 kB 56.7 MB/s
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (6.0.1)
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.6.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 53.1 MB/s
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.3 MB/s
# Collecting cloudpickle<3,>=2.1.0
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.22.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.9 MB/s
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.12.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (508 kB)
#      |████████████████████████████████| 508 kB 56.4 MB/s
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting protobuf<4.0.0dev,>=3.12.0
#   Downloading protobuf-3.19.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 47.0 MB/s
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.1.1)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.6.0.66)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.9.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.10.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.7.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.27.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 48.5 MB/s
# Building wheels for collected packages: object-detection, py-cpuinfo, dill, avro-python3, docopt, seqeval
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696118 sha256=0fe373b2c5dbf44674c31f61bf23ee303dcdd1c808dd4ad240e84a1a24720b3f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qz9995s0/wheels/a9/26/bf/1cb2313ed4855917889b97658bf0a19999e3588e47867bdaee
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=dab37ca5c91788076a770c34f71cd9249a2832b873a2ee4112427e726c36ba20
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=077225f3997a04e07ee209aa4bdbdf8dd445bb00880b1cb052d5a00d1d1c8278
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44010 sha256=b7d27ac563b87136dd3e4ebb431f67ba4f9b12cd2edcbb4e1cff306718a028c4
#   Stored in directory: /root/.cache/pip/wheels/d6/e5/b1/6b151d9b535ee50aaa6ab27d145a0104b6df02e5636f0376da
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=4478db039ef9af8b952431f44defb84e4c41abb4bd0e85a924a779746ae90329
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=0d353ed082a7c292653d9de55c5f8545abe6c5045fbe7f45570d0b14f23f86d2
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built object-detection py-cpuinfo dill avro-python3 docopt seqeval
# Installing collected packages: requests, pyparsing, protobuf, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, keras, flatbuffers, tensorflow, portalocker, docopt, dill, colorama, tf-slim, tensorflow-text, tensorflow-model-optimization, tensorflow-addons, seqeval, sentencepiece, sacrebleu, pyyaml, pymongo, py-cpuinfo, proto-plus, orjson, opencv-python-headless, immutabledict, hdfs, fastavro, cloudpickle, tf-models-official, tensorflow-io, lvis, avro-python3, apache-beam, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.26.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.26.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.26.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.0
#     Uninstalling tensorflow-2.9.0:
#       Successfully uninstalled tensorflow-2.9.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Uninstalling dill-0.3.5.1:
#       Successfully uninstalled dill-0.3.5.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.2.0
#     Uninstalling pymongo-4.2.0:
#       Successfully uninstalled pymongo-4.2.0
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.6.0.66
#     Uninstalling opencv-python-headless-4.6.0.66:
#       Successfully uninstalled opencv-python-headless-4.6.0.66
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.5.0
#     Uninstalling cloudpickle-1.5.0:
#       Successfully uninstalled cloudpickle-1.5.0
# Successfully installed apache-beam-2.41.0 avro-python3-1.10.2 cloudpickle-2.2.0 colorama-0.4.5 dill-0.3.1.1 docopt-0.6.2 fastavro-1.6.1 flatbuffers-2.0.7 hdfs-2.7.0 immutabledict-2.2.1 keras-2.10.0 lvis-0.5.3 object-detection-0.1 opencv-python-headless-4.5.2.52 orjson-3.8.0 portalocker-2.5.1 proto-plus-1.22.1 protobuf-3.19.5 py-cpuinfo-8.0.0 pymongo-3.12.3 pyparsing-2.4.7 pyyaml-5.4.1 requests-2.28.1 sacrebleu-2.2.0 sentencepiece-0.1.97 seqeval-1.2.2 tensorboard-2.10.0 tensorflow-2.10.0 tensorflow-addons-0.18.0 tensorflow-estimator-2.10.0 tensorflow-io-0.27.0 tensorflow-io-gcs-filesystem-0.27.0 tensorflow-model-optimization-0.7.3 tensorflow-text-2.10.0 tf-models-official-2.10.0 tf-slim-1.1.0

# %%
# Verify installation
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# !python {VERIFICATION_SCRIPT}
# Out:
# 2022-09-21 03:55:04.483220: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-21 03:55:05.438884: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-09-21 03:55:05.439056: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-09-21 03:55:05.439080: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Running tests under Python 3.7.14: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-09-21 03:55:09.414242: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# W0921 03:55:09.853524 140254197675904 model_builder.py:1102] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.78s
# I0921 03:55:10.171031 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.78s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.66s
# I0921 03:55:10.834856 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.66s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.33s
# I0921 03:55:11.161139 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.33s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.49s
# I0921 03:55:11.655604 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.49s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 3.04s
# I0921 03:55:14.693375 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 3.04s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0921 03:55:14.701320 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.05s
# I0921 03:55:14.748678 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# I0921 03:55:14.772870 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I0921 03:55:14.796891 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.16s
# I0921 03:55:14.955632 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.16s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.15s
# I0921 03:55:15.104038 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.15s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.19s
# I0921 03:55:15.294005 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.19s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.17s
# I0921 03:55:15.468059 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.17s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.17s
# I0921 03:55:15.642656 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.17s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.06s
# I0921 03:55:15.707458 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0921 03:55:15.991147 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0921 03:55:15.991328 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 64
# I0921 03:55:15.991421 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 3
# I0921 03:55:15.994083 140254197675904 efficientnet_model.py:143] round_filter input=32 output=32
# I0921 03:55:16.031996 140254197675904 efficientnet_model.py:143] round_filter input=32 output=32
# I0921 03:55:16.032146 140254197675904 efficientnet_model.py:143] round_filter input=16 output=16
# I0921 03:55:16.137434 140254197675904 efficientnet_model.py:143] round_filter input=16 output=16
# I0921 03:55:16.137688 140254197675904 efficientnet_model.py:143] round_filter input=24 output=24
# I0921 03:55:16.459341 140254197675904 efficientnet_model.py:143] round_filter input=24 output=24
# I0921 03:55:16.459572 140254197675904 efficientnet_model.py:143] round_filter input=40 output=40
# I0921 03:55:16.780151 140254197675904 efficientnet_model.py:143] round_filter input=40 output=40
# I0921 03:55:16.780424 140254197675904 efficientnet_model.py:143] round_filter input=80 output=80
# I0921 03:55:17.249338 140254197675904 efficientnet_model.py:143] round_filter input=80 output=80
# I0921 03:55:17.249571 140254197675904 efficientnet_model.py:143] round_filter input=112 output=112
# I0921 03:55:17.938828 140254197675904 efficientnet_model.py:143] round_filter input=112 output=112
# I0921 03:55:17.939168 140254197675904 efficientnet_model.py:143] round_filter input=192 output=192
# I0921 03:55:18.504114 140254197675904 efficientnet_model.py:143] round_filter input=192 output=192
# I0921 03:55:18.504303 140254197675904 efficientnet_model.py:143] round_filter input=320 output=320
# I0921 03:55:18.634315 140254197675904 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0921 03:55:18.710842 140254197675904 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0921 03:55:18.804820 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0921 03:55:18.805011 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 88
# I0921 03:55:18.805090 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 4
# I0921 03:55:18.807116 140254197675904 efficientnet_model.py:143] round_filter input=32 output=32
# I0921 03:55:18.830646 140254197675904 efficientnet_model.py:143] round_filter input=32 output=32
# I0921 03:55:18.830838 140254197675904 efficientnet_model.py:143] round_filter input=16 output=16
# I0921 03:55:19.067734 140254197675904 efficientnet_model.py:143] round_filter input=16 output=16
# I0921 03:55:19.067945 140254197675904 efficientnet_model.py:143] round_filter input=24 output=24
# I0921 03:55:19.545780 140254197675904 efficientnet_model.py:143] round_filter input=24 output=24
# I0921 03:55:19.546017 140254197675904 efficientnet_model.py:143] round_filter input=40 output=40
# I0921 03:55:19.953087 140254197675904 efficientnet_model.py:143] round_filter input=40 output=40
# I0921 03:55:19.953269 140254197675904 efficientnet_model.py:143] round_filter input=80 output=80
# I0921 03:55:20.542246 140254197675904 efficientnet_model.py:143] round_filter input=80 output=80
# I0921 03:55:20.542458 140254197675904 efficientnet_model.py:143] round_filter input=112 output=112
# I0921 03:55:21.201320 140254197675904 efficientnet_model.py:143] round_filter input=112 output=112
# I0921 03:55:21.201518 140254197675904 efficientnet_model.py:143] round_filter input=192 output=192
# I0921 03:55:21.770831 140254197675904 efficientnet_model.py:143] round_filter input=192 output=192
# I0921 03:55:21.771042 140254197675904 efficientnet_model.py:143] round_filter input=320 output=320
# I0921 03:55:22.009814 140254197675904 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0921 03:55:22.052072 140254197675904 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0921 03:55:22.128973 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0921 03:55:22.129181 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 112
# I0921 03:55:22.129278 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 5
# I0921 03:55:22.131260 140254197675904 efficientnet_model.py:143] round_filter input=32 output=32
# I0921 03:55:22.154553 140254197675904 efficientnet_model.py:143] round_filter input=32 output=32
# I0921 03:55:22.154758 140254197675904 efficientnet_model.py:143] round_filter input=16 output=16
# I0921 03:55:22.339546 140254197675904 efficientnet_model.py:143] round_filter input=16 output=16
# I0921 03:55:22.339822 140254197675904 efficientnet_model.py:143] round_filter input=24 output=24
# I0921 03:55:22.681868 140254197675904 efficientnet_model.py:143] round_filter input=24 output=24
# I0921 03:55:22.682080 140254197675904 efficientnet_model.py:143] round_filter input=40 output=48
# I0921 03:55:23.039844 140254197675904 efficientnet_model.py:143] round_filter input=40 output=48
# I0921 03:55:23.040016 140254197675904 efficientnet_model.py:143] round_filter input=80 output=88
# I0921 03:55:23.519637 140254197675904 efficientnet_model.py:143] round_filter input=80 output=88
# I0921 03:55:23.519827 140254197675904 efficientnet_model.py:143] round_filter input=112 output=120
# I0921 03:55:23.998342 140254197675904 efficientnet_model.py:143] round_filter input=112 output=120
# I0921 03:55:23.998531 140254197675904 efficientnet_model.py:143] round_filter input=192 output=208
# I0921 03:55:24.600534 140254197675904 efficientnet_model.py:143] round_filter input=192 output=208
# I0921 03:55:24.600750 140254197675904 efficientnet_model.py:143] round_filter input=320 output=352
# I0921 03:55:24.850000 140254197675904 efficientnet_model.py:143] round_filter input=1280 output=1408
# I0921 03:55:24.901529 140254197675904 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0921 03:55:24.974985 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0921 03:55:24.975152 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 160
# I0921 03:55:24.975236 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 6
# I0921 03:55:24.977157 140254197675904 efficientnet_model.py:143] round_filter input=32 output=40
# I0921 03:55:25.003285 140254197675904 efficientnet_model.py:143] round_filter input=32 output=40
# I0921 03:55:25.003447 140254197675904 efficientnet_model.py:143] round_filter input=16 output=24
# I0921 03:55:25.200739 140254197675904 efficientnet_model.py:143] round_filter input=16 output=24
# I0921 03:55:25.200928 140254197675904 efficientnet_model.py:143] round_filter input=24 output=32
# I0921 03:55:25.547117 140254197675904 efficientnet_model.py:143] round_filter input=24 output=32
# I0921 03:55:25.547304 140254197675904 efficientnet_model.py:143] round_filter input=40 output=48
# I0921 03:55:26.108542 140254197675904 efficientnet_model.py:143] round_filter input=40 output=48
# I0921 03:55:26.108744 140254197675904 efficientnet_model.py:143] round_filter input=80 output=96
# I0921 03:55:26.700097 140254197675904 efficientnet_model.py:143] round_filter input=80 output=96
# I0921 03:55:26.700295 140254197675904 efficientnet_model.py:143] round_filter input=112 output=136
# I0921 03:55:27.298072 140254197675904 efficientnet_model.py:143] round_filter input=112 output=136
# I0921 03:55:27.298291 140254197675904 efficientnet_model.py:143] round_filter input=192 output=232
# I0921 03:55:28.008984 140254197675904 efficientnet_model.py:143] round_filter input=192 output=232
# I0921 03:55:28.009197 140254197675904 efficientnet_model.py:143] round_filter input=320 output=384
# I0921 03:55:28.256856 140254197675904 efficientnet_model.py:143] round_filter input=1280 output=1536
# I0921 03:55:28.307422 140254197675904 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0921 03:55:28.383481 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0921 03:55:28.383676 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 224
# I0921 03:55:28.383757 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 7
# I0921 03:55:28.385692 140254197675904 efficientnet_model.py:143] round_filter input=32 output=48
# I0921 03:55:28.412649 140254197675904 efficientnet_model.py:143] round_filter input=32 output=48
# I0921 03:55:28.412772 140254197675904 efficientnet_model.py:143] round_filter input=16 output=24
# I0921 03:55:28.599127 140254197675904 efficientnet_model.py:143] round_filter input=16 output=24
# I0921 03:55:28.599308 140254197675904 efficientnet_model.py:143] round_filter input=24 output=32
# I0921 03:55:29.053898 140254197675904 efficientnet_model.py:143] round_filter input=24 output=32
# I0921 03:55:29.054138 140254197675904 efficientnet_model.py:143] round_filter input=40 output=56
# I0921 03:55:29.533962 140254197675904 efficientnet_model.py:143] round_filter input=40 output=56
# I0921 03:55:29.534188 140254197675904 efficientnet_model.py:143] round_filter input=80 output=112
# I0921 03:55:30.226086 140254197675904 efficientnet_model.py:143] round_filter input=80 output=112
# I0921 03:55:30.226306 140254197675904 efficientnet_model.py:143] round_filter input=112 output=160
# I0921 03:55:30.932114 140254197675904 efficientnet_model.py:143] round_filter input=112 output=160
# I0921 03:55:30.932325 140254197675904 efficientnet_model.py:143] round_filter input=192 output=272
# I0921 03:55:31.878221 140254197675904 efficientnet_model.py:143] round_filter input=192 output=272
# I0921 03:55:31.878440 140254197675904 efficientnet_model.py:143] round_filter input=320 output=448
# I0921 03:55:32.118950 140254197675904 efficientnet_model.py:143] round_filter input=1280 output=1792
# I0921 03:55:32.168264 140254197675904 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0921 03:55:32.257004 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0921 03:55:32.257202 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 288
# I0921 03:55:32.257300 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 7
# I0921 03:55:32.259295 140254197675904 efficientnet_model.py:143] round_filter input=32 output=48
# I0921 03:55:32.282522 140254197675904 efficientnet_model.py:143] round_filter input=32 output=48
# I0921 03:55:32.282698 140254197675904 efficientnet_model.py:143] round_filter input=16 output=24
# I0921 03:55:32.554736 140254197675904 efficientnet_model.py:143] round_filter input=16 output=24
# I0921 03:55:32.555002 140254197675904 efficientnet_model.py:143] round_filter input=24 output=40
# I0921 03:55:33.138045 140254197675904 efficientnet_model.py:143] round_filter input=24 output=40
# I0921 03:55:33.138245 140254197675904 efficientnet_model.py:143] round_filter input=40 output=64
# I0921 03:55:33.714602 140254197675904 efficientnet_model.py:143] round_filter input=40 output=64
# I0921 03:55:33.714811 140254197675904 efficientnet_model.py:143] round_filter input=80 output=128
# I0921 03:55:34.781992 140254197675904 efficientnet_model.py:143] round_filter input=80 output=128
# I0921 03:55:34.782203 140254197675904 efficientnet_model.py:143] round_filter input=112 output=176
# I0921 03:55:35.600322 140254197675904 efficientnet_model.py:143] round_filter input=112 output=176
# I0921 03:55:35.600548 140254197675904 efficientnet_model.py:143] round_filter input=192 output=304
# I0921 03:55:36.659233 140254197675904 efficientnet_model.py:143] round_filter input=192 output=304
# I0921 03:55:36.659413 140254197675904 efficientnet_model.py:143] round_filter input=320 output=512
# I0921 03:55:37.018056 140254197675904 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0921 03:55:37.065339 140254197675904 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0921 03:55:37.165665 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0921 03:55:37.165838 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0921 03:55:37.165916 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 8
# I0921 03:55:37.167751 140254197675904 efficientnet_model.py:143] round_filter input=32 output=56
# I0921 03:55:37.192151 140254197675904 efficientnet_model.py:143] round_filter input=32 output=56
# I0921 03:55:37.192259 140254197675904 efficientnet_model.py:143] round_filter input=16 output=32
# I0921 03:55:37.486665 140254197675904 efficientnet_model.py:143] round_filter input=16 output=32
# I0921 03:55:37.486941 140254197675904 efficientnet_model.py:143] round_filter input=24 output=40
# I0921 03:55:38.180605 140254197675904 efficientnet_model.py:143] round_filter input=24 output=40
# I0921 03:55:38.180880 140254197675904 efficientnet_model.py:143] round_filter input=40 output=72
# I0921 03:55:38.899265 140254197675904 efficientnet_model.py:143] round_filter input=40 output=72
# I0921 03:55:38.899507 140254197675904 efficientnet_model.py:143] round_filter input=80 output=144
# I0921 03:55:39.840417 140254197675904 efficientnet_model.py:143] round_filter input=80 output=144
# I0921 03:55:39.840626 140254197675904 efficientnet_model.py:143] round_filter input=112 output=200
# I0921 03:55:40.779841 140254197675904 efficientnet_model.py:143] round_filter input=112 output=200
# I0921 03:55:40.780042 140254197675904 efficientnet_model.py:143] round_filter input=192 output=344
# I0921 03:55:42.078976 140254197675904 efficientnet_model.py:143] round_filter input=192 output=344
# I0921 03:55:42.079148 140254197675904 efficientnet_model.py:143] round_filter input=320 output=576
# I0921 03:55:42.435705 140254197675904 efficientnet_model.py:143] round_filter input=1280 output=2304
# I0921 03:55:42.481671 140254197675904 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0921 03:55:42.593940 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0921 03:55:42.594128 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0921 03:55:42.594208 140254197675904 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 8
# I0921 03:55:42.596128 140254197675904 efficientnet_model.py:143] round_filter input=32 output=64
# I0921 03:55:42.621715 140254197675904 efficientnet_model.py:143] round_filter input=32 output=64
# I0921 03:55:42.621874 140254197675904 efficientnet_model.py:143] round_filter input=16 output=32
# I0921 03:55:43.258148 140254197675904 efficientnet_model.py:143] round_filter input=16 output=32
# I0921 03:55:43.258362 140254197675904 efficientnet_model.py:143] round_filter input=24 output=48
# I0921 03:55:44.077943 140254197675904 efficientnet_model.py:143] round_filter input=24 output=48
# I0921 03:55:44.078126 140254197675904 efficientnet_model.py:143] round_filter input=40 output=80
# I0921 03:55:44.898548 140254197675904 efficientnet_model.py:143] round_filter input=40 output=80
# I0921 03:55:44.898775 140254197675904 efficientnet_model.py:143] round_filter input=80 output=160
# I0921 03:55:46.057794 140254197675904 efficientnet_model.py:143] round_filter input=80 output=160
# I0921 03:55:46.057979 140254197675904 efficientnet_model.py:143] round_filter input=112 output=224
# I0921 03:55:47.235289 140254197675904 efficientnet_model.py:143] round_filter input=112 output=224
# I0921 03:55:47.235510 140254197675904 efficientnet_model.py:143] round_filter input=192 output=384
# I0921 03:55:48.737116 140254197675904 efficientnet_model.py:143] round_filter input=192 output=384
# I0921 03:55:48.737318 140254197675904 efficientnet_model.py:143] round_filter input=320 output=640
# I0921 03:55:49.207686 140254197675904 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0921 03:55:49.264625 140254197675904 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 33.69s
# I0921 03:55:49.401410 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 33.69s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0921 03:55:49.430103 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0921 03:55:49.432208 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0921 03:55:49.432719 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0921 03:55:49.434405 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0921 03:55:49.436017 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0921 03:55:49.436473 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0921 03:55:49.437557 140254197675904 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 41.046s
#
# OK (skipped=1)

# %%
# test if TF object detection library could be loaded
import object_detection

# %%
# reinstall TF and restart runtime
# !pip install tensorflow==2.7.0

# %% [markdown]
# ### Download and decompress TF pretrained model

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2022-09-21 03:55:50--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 108.177.97.128, 2404:6800:4008:c00::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|108.177.97.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  89.2MB/s    in 0.2s
#
# 2022-09-21 03:55:51 (89.2 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# ### Download training images

# %%
import shutil

if os.path.exists('object_detection_using_tensorflow'):
    shutil.rmtree('object_detection_using_tensorflow')

# !git clone https://github.com/jackliu333/object_detection_using_tensorflow.git
# Out:
# Cloning into 'object_detection_using_tensorflow'...
# remote: Enumerating objects: 3794, done.
# remote: Counting objects: 100% (416/416), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 3794 (delta 218), reused 409 (delta 217), pack-reused 3378
# Receiving objects: 100% (3794/3794), 1.64 GiB | 24.80 MiB/s, done.
# Resolving deltas: 100% (2231/2231), done.
# Checking out files: 100% (5564/5564), done.

# %% [markdown]
# ### Create label map

# %%
# labels = [{'name':'Apple', 'id':1},
#           {'name':'Avocado', 'id':2},
#           {'name':'Banana', 'id':3},
#           {'name':'Cabbage', 'id':4},
#           {'name':'Carrot', 'id':5},
#           {'name':'Potato', 'id':6}]
# labels = [{'name':'Canned_Sardines_and_Mackerel', 'id':1}, 
#           {'name':'Canned_Baked_Beans', 'id':2}, 
#           {'name':'Biscuits', 'id':3},
#           {'name':'Halal', 'id':4},
#           {'name':'Kitkat', 'id':5},
#           {'name':'Wafers', 'id':6}]

labels = [{'name':'cookies_1g-99g', 'id':1}, 
          {'name':'cookies_1kg-1.99kg', 'id':2}, 
          {'name':'cookies_100g-199g', 'id':3},
          {'name':'cookies_200g-299g', 'id':4},
          {'name':'crackers_100g-199g', 'id':5},
          {'name':'crackers_200g-299g', 'id':6},
          {'name':'crackers_300g-399g', 'id':7},
          {'name':'crackers_400g-499g', 'id':8},
          {'name':'sardines_100g-199g', 'id':9},
          {'name':'sardines_400g-499g', 'id':10},
          {'name':'Baked beans_400-499g', 'id':11},
          {'name':'cookies_300g-399g', 'id':12},
          {'name':'cookies_400g-499g', 'id':13},
          {'name':'cookies_500g-599g', 'id':14},
          {'name':'cookies_600g-699g', 'id':15},
          {'name':'crackers_1g-99g', 'id':16},
          {'name':'crackers_800g-899g', 'id':17},
          {'name':'halal', 'id':18}]

# labels = [{'name':'cookies_1g-99g', 'id':1}, 
#           {'name':'cookies_1kg-1.99kg', 'id':2},
#           {'name':'cookies_100g-199g', 'id':3},
#           {'name':'cookies_200g-299g', 'id':4},
#           {'name':'crackers_100g-199g', 'id':5},
#           {'name':'crackers_200g-299g', 'id':6},
#           {'name':'crackers_300g-399g', 'id':7},
#           {'name':'crackers_400g-499g', 'id':8}]

# labels = [{'name':'Baked beans_400-499g', 'id':1}]

with open(training_files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# ### Split into train test folders

# %%
tmp_folders = ['train', 'test']

for i in tmp_folders:
    if os.path.exists(os.path.join(paths['IMAGE_PATH'], i)):
        shutil.rmtree(os.path.join(paths['IMAGE_PATH'], i))
        # !mkdir -p {os.path.join(paths['IMAGE_PATH'], i)}
    else:
        # !mkdir -p {os.path.join(paths['IMAGE_PATH'], i)}

# %%
import shutil

for i in range(len(labels)):
    # print(labels[i]['name'])
    from_path = os.path.join('object_detection_using_tensorflow','images5',labels[i]['name'])
    # print(from_path)

    # get unique file names
    tmp_files = os.listdir(from_path)
    tmp_names = []
    tmp_file_types = []
    for tmp_file in tmp_files:
        tmp_name = os.path.splitext(tmp_file)[0]
        tmp_file_type = os.path.splitext(tmp_file)[1]
        tmp_names.append(tmp_name)
        tmp_file_types.append(tmp_file_type)
    tmp_names = list(set(tmp_names))
    tmp_names = [i for i in tmp_names if i != '.DS_Store']
    tmp_file_types = list(set(tmp_file_types))
    tmp_file_types = [i for i in tmp_file_types if len(i) != 0]
    # random shuffle the files
    random.shuffle(tmp_names)
    
    # training and test files
    tmp_names_train = tmp_names[0:int(len(tmp_names)*0.9)]
    tmp_names_test = [i for i in tmp_names if i not in tmp_names_train]

    # move into respective target folders
    for tmp_name in tmp_names_train:
        for tmp_file_type in tmp_file_types:
            tmp_name_full = tmp_name + tmp_file_type
            if(os.path.exists(os.path.join(from_path, tmp_name_full))):
                shutil.copy(os.path.join(from_path, tmp_name_full), \
                            os.path.join(paths['IMAGE_PATH'], "train"))

    for tmp_name in tmp_names_test:
        for tmp_file_type in tmp_file_types:
            tmp_name_full = tmp_name + tmp_file_type
            if(os.path.exists(os.path.join(from_path, tmp_name_full))):    
                shutil.copy(os.path.join(from_path, tmp_name_full), \
                            os.path.join(paths['IMAGE_PATH'], "test"))

# %%
# from_path
# os.listdir(from_path)

# %% [markdown]
# ### Create TF Record

# %%
# download conversion script
if not os.path.exists(training_files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}
# Out:
# Cloning into 'Tensorflow/scripts'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# convert to TF record format
# !python {training_files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {training_files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {training_files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {training_files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# 2022-09-21 03:57:27.495538: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# 2022-09-21 03:57:34.840689: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# ### Copy model configuration file to training folder

# %%
# !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {paths['CHECKPOINT_PATH']}

# %% [markdown]
# ### Update configuration file for transfer learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# Read current configuration file
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(training_files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)  

# Update based on new labels
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= training_files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = training_files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# # Add more data augmentation
# upd_dict = {'data_augmentation_options':{'random_rgb_to_gray' : {}}}
# # pipeline_config.train_config = upd_dict
# pipeline_config.train_config.data_augmentation_options.random_rgb_to_gray = []
# # Load the pipeline config as a dictionary
# pipeline_config_dict = config_util.get_configs_from_pipeline_file(pipeline_config)
# # update dict entry

# pipeline_config_dict["train_config"].update(upd_dict)
# # Convert the pipeline dict back to a protobuf object
# pipeline_config = config_util.create_pipeline_proto_from_configs(pipeline_config_dict)

# Write to configuration file
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(training_files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # Model training

# %%
# fix opencv-python version issue 
# !pip uninstall opencv-python-headless 
# !pip install opencv-python-headless==4.1.2.30
# Out:
# Found existing installation: opencv-python-headless 4.5.2.52
# Uninstalling opencv-python-headless-4.5.2.52:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/cv2/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless-4.5.2.52.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavcodec-8daa01ff.so.58.109.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavformat-06a336f2.so.58.61.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavutil-01d48d95.so.56.60.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libbz2-a273e504.so.1.0.6
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libcrypto-098682aa.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libpng15-c2ffaf3d.so.15.13.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libssl-f3db6a3b.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libswresample-4767dc06.so.3.8.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libswscale-2d2bce5d.so.5.8.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libvpx-14094576.so.6.3.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libz-d8a329de.so.1.2.7
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/cv2/qt/fonts/DejaVuSans-Bold.ttf
#     /usr/local/lib/python3.7/dist-packages/cv2/qt/fonts/DejaVuSans-BoldOblique.ttf
#     /usr/local/lib/python3.7/dist-packages/cv2/qt/fonts/DejaVuSans-ExtraLight.ttf
#     /usr/local/lib/python3.7/dist-packages/cv2/qt/fonts/DejaVuSans-Oblique.ttf
#     /usr/local/lib/python3.7/dist-packages/cv2/qt/fonts/DejaVuSans.ttf
#     /usr/local/lib/python3.7/dist-packages/cv2/qt/fonts/DejaVuSansCondensed-Bold.ttf
#     /usr/local/lib/python3.7/dist-packages/cv2/qt/fonts/DejaVuSansCondensed-BoldOblique.ttf
#     /usr/local/lib/python3.7/dist-packages/cv2/qt/fonts/DejaVuSansCondensed-Oblique.ttf
#     /usr/local/lib/python3.7/dist-packages/cv2/qt/fonts/DejaVuSansCondensed.ttf
#     /usr/local/lib/python3.7/dist-packages/cv2/qt/plugins/platforms/libqxcb.so
# Proceed (y/n)? y
#   Successfully uninstalled opencv-python-headless-4.5.2.52
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python-headless==4.1.2.30
#   Downloading opencv_python_headless-4.1.2.30-cp37-cp37m-manylinux1_x86_64.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 190 kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless==4.1.2.30) (1.21.6)
# Installing collected packages: opencv-python-headless
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.10.0 requires opencv-python-headless==4.5.2.52, but you have opencv-python-headless 4.1.2.30 which is incompatible.
# Successfully installed opencv-python-headless-4.1.2.30

# %%
# os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
# # import fileinput
# file_path = '/usr/local/lib/python3.7/dist-packages/official/modeling/optimization/optimizer_factory.py'
# # fields = {"adamw_experimental": "tf.keras.optimizers.Adam"}

# with open(file_path, 'r') as file:
  
#     data = file.read()
#     data = data.replace('tf.keras.optimizers.experimental.AdamW', 'tf.keras.optimizers.AdamW')
 
# with open(file_path, 'w') as file:
  
#     # Writing the replaced data in our
#     # text file
#     file.write(data)

# # print(test)

# %%
training_steps = 30000
check_point = 'ckpt-31'
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],training_files['PIPELINE_CONFIG'],training_steps)
# !{command}
# Out:
# 2022-09-21 04:06:22.334830: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-21 04:06:23.295003: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-09-21 04:06:23.295121: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-09-21 04:06:23.295144: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-09-21 04:06:27.151750: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0921 04:06:27.312051 140011597215616 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 30000
# I0921 04:06:27.318557 140011597215616 config_util.py:552] Maybe overwriting train_steps: 30000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0921 04:06:27.318748 140011597215616 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0921 04:06:27.355044 140011597215616 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0921 04:06:27.378284 140011597215616 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0921 04:06:27.381981 140011597215616 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0921 04:06:27.382157 140011597215616 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0921 04:06:27.382283 140011597215616 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0921 04:06:27.396269 140011597215616 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0921 04:06:27.424240 140011597215616 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0921 04:06:37.278184 140011597215616 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0921 04:06:41.661167 140011597215616 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0921 04:06:43.461060 140011597215616 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   "`tf.keras.backend.set_learning_phase` is deprecated and "
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0921 04:07:22.194730 140011597215616 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0921 04:07:22.198333 140011597215616 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0921 04:07:22.201436 140011597215616 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0921 04:07:22.202787 140011597215616 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0921 04:07:22.207114 140011597215616 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0921 04:07:22.208374 140011597215616 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0921 04:07:22.212800 140011597215616 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0921 04:07:22.214482 140011597215616 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0921 04:07:22.217920 140011597215616 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0921 04:07:22.219180 140011597215616 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0921 04:07:23.703462 140006664414976 deprecation.py:560] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.517s
# I0921 04:08:14.948322 140011597215616 model_lib_v2.py:707] Step 100 per-step time 0.517s
# INFO:tensorflow:{'Loss/classification_loss': 0.88417894,
#  'Loss/localization_loss': 0.3424284,
#  'Loss/regularization_loss': 0.15383053,
#  'Loss/total_loss': 1.3804379,
#  'learning_rate': 0.0319994}
# I0921 04:08:14.948754 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.88417894,
#  'Loss/localization_loss': 0.3424284,
#  'Loss/regularization_loss': 0.15383053,
#  'Loss/total_loss': 1.3804379,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.091s
# I0921 04:08:23.993234 140011597215616 model_lib_v2.py:707] Step 200 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.39888564,
#  'Loss/localization_loss': 0.20355487,
#  'Loss/regularization_loss': 0.15404695,
#  'Loss/total_loss': 0.7564874,
#  'learning_rate': 0.0373328}
# I0921 04:08:23.993805 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.39888564,
#  'Loss/localization_loss': 0.20355487,
#  'Loss/regularization_loss': 0.15404695,
#  'Loss/total_loss': 0.7564874,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.099s
# I0921 04:08:33.882973 140011597215616 model_lib_v2.py:707] Step 300 per-step time 0.099s
# INFO:tensorflow:{'Loss/classification_loss': 0.421676,
#  'Loss/localization_loss': 0.16547163,
#  'Loss/regularization_loss': 0.15384011,
#  'Loss/total_loss': 0.7409878,
#  'learning_rate': 0.0426662}
# I0921 04:08:33.883506 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.421676,
#  'Loss/localization_loss': 0.16547163,
#  'Loss/regularization_loss': 0.15384011,
#  'Loss/total_loss': 0.7409878,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.089s
# I0921 04:08:42.748301 140011597215616 model_lib_v2.py:707] Step 400 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.43981352,
#  'Loss/localization_loss': 0.12717839,
#  'Loss/regularization_loss': 0.15359192,
#  'Loss/total_loss': 0.72058386,
#  'learning_rate': 0.047999598}
# I0921 04:08:42.748685 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.43981352,
#  'Loss/localization_loss': 0.12717839,
#  'Loss/regularization_loss': 0.15359192,
#  'Loss/total_loss': 0.72058386,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.088s
# I0921 04:08:51.626957 140011597215616 model_lib_v2.py:707] Step 500 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.45243973,
#  'Loss/localization_loss': 0.07640878,
#  'Loss/regularization_loss': 0.15331732,
#  'Loss/total_loss': 0.68216586,
#  'learning_rate': 0.053333}
# I0921 04:08:51.631244 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.45243973,
#  'Loss/localization_loss': 0.07640878,
#  'Loss/regularization_loss': 0.15331732,
#  'Loss/total_loss': 0.68216586,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.089s
# I0921 04:09:00.508129 140011597215616 model_lib_v2.py:707] Step 600 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.4337938,
#  'Loss/localization_loss': 0.2123942,
#  'Loss/regularization_loss': 0.15299611,
#  'Loss/total_loss': 0.79918414,
#  'learning_rate': 0.0586664}
# I0921 04:09:00.508642 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.4337938,
#  'Loss/localization_loss': 0.2123942,
#  'Loss/regularization_loss': 0.15299611,
#  'Loss/total_loss': 0.79918414,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.091s
# I0921 04:09:09.592985 140011597215616 model_lib_v2.py:707] Step 700 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.35077587,
#  'Loss/localization_loss': 0.045588918,
#  'Loss/regularization_loss': 0.15263452,
#  'Loss/total_loss': 0.5489993,
#  'learning_rate': 0.0639998}
# I0921 04:09:09.593447 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.35077587,
#  'Loss/localization_loss': 0.045588918,
#  'Loss/regularization_loss': 0.15263452,
#  'Loss/total_loss': 0.5489993,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.090s
# I0921 04:09:18.577664 140011597215616 model_lib_v2.py:707] Step 800 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.33963412,
#  'Loss/localization_loss': 0.1370414,
#  'Loss/regularization_loss': 0.15230387,
#  'Loss/total_loss': 0.6289794,
#  'learning_rate': 0.069333196}
# I0921 04:09:18.578069 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.33963412,
#  'Loss/localization_loss': 0.1370414,
#  'Loss/regularization_loss': 0.15230387,
#  'Loss/total_loss': 0.6289794,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.088s
# I0921 04:09:27.430336 140011597215616 model_lib_v2.py:707] Step 900 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.30271634,
#  'Loss/localization_loss': 0.10350961,
#  'Loss/regularization_loss': 0.1518444,
#  'Loss/total_loss': 0.55807036,
#  'learning_rate': 0.074666604}
# I0921 04:09:27.430841 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.30271634,
#  'Loss/localization_loss': 0.10350961,
#  'Loss/regularization_loss': 0.1518444,
#  'Loss/total_loss': 0.55807036,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.089s
# I0921 04:09:36.275582 140011597215616 model_lib_v2.py:707] Step 1000 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.5868007,
#  'Loss/localization_loss': 0.17772792,
#  'Loss/regularization_loss': 0.15143432,
#  'Loss/total_loss': 0.91596293,
#  'learning_rate': 0.08}
# I0921 04:09:36.276049 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.5868007,
#  'Loss/localization_loss': 0.17772792,
#  'Loss/regularization_loss': 0.15143432,
#  'Loss/total_loss': 0.91596293,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.104s
# I0921 04:09:46.690950 140011597215616 model_lib_v2.py:707] Step 1100 per-step time 0.104s
# INFO:tensorflow:{'Loss/classification_loss': 0.3448383,
#  'Loss/localization_loss': 0.040280804,
#  'Loss/regularization_loss': 0.15113607,
#  'Loss/total_loss': 0.5362551,
#  'learning_rate': 0.07999918}
# I0921 04:09:46.691297 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.3448383,
#  'Loss/localization_loss': 0.040280804,
#  'Loss/regularization_loss': 0.15113607,
#  'Loss/total_loss': 0.5362551,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.087s
# I0921 04:09:55.374011 140011597215616 model_lib_v2.py:707] Step 1200 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.20998137,
#  'Loss/localization_loss': 0.069728956,
#  'Loss/regularization_loss': 0.1505893,
#  'Loss/total_loss': 0.43029964,
#  'learning_rate': 0.079996705}
# I0921 04:09:55.374553 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.20998137,
#  'Loss/localization_loss': 0.069728956,
#  'Loss/regularization_loss': 0.1505893,
#  'Loss/total_loss': 0.43029964,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.084s
# I0921 04:10:03.818894 140011597215616 model_lib_v2.py:707] Step 1300 per-step time 0.084s
# INFO:tensorflow:{'Loss/classification_loss': 0.23251282,
#  'Loss/localization_loss': 0.042621218,
#  'Loss/regularization_loss': 0.15009911,
#  'Loss/total_loss': 0.42523313,
#  'learning_rate': 0.0799926}
# I0921 04:10:03.819323 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.23251282,
#  'Loss/localization_loss': 0.042621218,
#  'Loss/regularization_loss': 0.15009911,
#  'Loss/total_loss': 0.42523313,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.088s
# I0921 04:10:12.580579 140011597215616 model_lib_v2.py:707] Step 1400 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.28603733,
#  'Loss/localization_loss': 0.03790862,
#  'Loss/regularization_loss': 0.14966226,
#  'Loss/total_loss': 0.4736082,
#  'learning_rate': 0.07998685}
# I0921 04:10:12.581139 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.28603733,
#  'Loss/localization_loss': 0.03790862,
#  'Loss/regularization_loss': 0.14966226,
#  'Loss/total_loss': 0.4736082,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.093s
# I0921 04:10:21.842034 140011597215616 model_lib_v2.py:707] Step 1500 per-step time 0.093s
# INFO:tensorflow:{'Loss/classification_loss': 0.36213732,
#  'Loss/localization_loss': 0.08709816,
#  'Loss/regularization_loss': 0.14922191,
#  'Loss/total_loss': 0.5984574,
#  'learning_rate': 0.07997945}
# I0921 04:10:21.842508 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.36213732,
#  'Loss/localization_loss': 0.08709816,
#  'Loss/regularization_loss': 0.14922191,
#  'Loss/total_loss': 0.5984574,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.088s
# I0921 04:10:30.678240 140011597215616 model_lib_v2.py:707] Step 1600 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.27379158,
#  'Loss/localization_loss': 0.043316852,
#  'Loss/regularization_loss': 0.1487161,
#  'Loss/total_loss': 0.46582454,
#  'learning_rate': 0.079970405}
# I0921 04:10:30.678726 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.27379158,
#  'Loss/localization_loss': 0.043316852,
#  'Loss/regularization_loss': 0.1487161,
#  'Loss/total_loss': 0.46582454,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.091s
# I0921 04:10:39.811995 140011597215616 model_lib_v2.py:707] Step 1700 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.23526517,
#  'Loss/localization_loss': 0.050517093,
#  'Loss/regularization_loss': 0.14815618,
#  'Loss/total_loss': 0.43393844,
#  'learning_rate': 0.07995972}
# I0921 04:10:39.812483 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.23526517,
#  'Loss/localization_loss': 0.050517093,
#  'Loss/regularization_loss': 0.14815618,
#  'Loss/total_loss': 0.43393844,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.088s
# I0921 04:10:48.628867 140011597215616 model_lib_v2.py:707] Step 1800 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.4273032,
#  'Loss/localization_loss': 0.03687506,
#  'Loss/regularization_loss': 0.14767475,
#  'Loss/total_loss': 0.611853,
#  'learning_rate': 0.0799474}
# I0921 04:10:48.629343 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.4273032,
#  'Loss/localization_loss': 0.03687506,
#  'Loss/regularization_loss': 0.14767475,
#  'Loss/total_loss': 0.611853,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.090s
# I0921 04:10:57.629927 140011597215616 model_lib_v2.py:707] Step 1900 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.20925008,
#  'Loss/localization_loss': 0.13443513,
#  'Loss/regularization_loss': 0.14709058,
#  'Loss/total_loss': 0.4907758,
#  'learning_rate': 0.07993342}
# I0921 04:10:57.630393 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.20925008,
#  'Loss/localization_loss': 0.13443513,
#  'Loss/regularization_loss': 0.14709058,
#  'Loss/total_loss': 0.4907758,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.089s
# I0921 04:11:06.521315 140011597215616 model_lib_v2.py:707] Step 2000 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.34605002,
#  'Loss/localization_loss': 0.060630195,
#  'Loss/regularization_loss': 0.14656751,
#  'Loss/total_loss': 0.55324775,
#  'learning_rate': 0.07991781}
# I0921 04:11:06.521789 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.34605002,
#  'Loss/localization_loss': 0.060630195,
#  'Loss/regularization_loss': 0.14656751,
#  'Loss/total_loss': 0.55324775,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.100s
# I0921 04:11:16.558456 140011597215616 model_lib_v2.py:707] Step 2100 per-step time 0.100s
# INFO:tensorflow:{'Loss/classification_loss': 0.25588375,
#  'Loss/localization_loss': 0.040948052,
#  'Loss/regularization_loss': 0.1460712,
#  'Loss/total_loss': 0.442903,
#  'learning_rate': 0.07990056}
# I0921 04:11:16.559006 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.25588375,
#  'Loss/localization_loss': 0.040948052,
#  'Loss/regularization_loss': 0.1460712,
#  'Loss/total_loss': 0.442903,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.089s
# I0921 04:11:25.413109 140011597215616 model_lib_v2.py:707] Step 2200 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.11650901,
#  'Loss/localization_loss': 0.08239847,
#  'Loss/regularization_loss': 0.14565885,
#  'Loss/total_loss': 0.34456635,
#  'learning_rate': 0.07988167}
# I0921 04:11:25.413576 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.11650901,
#  'Loss/localization_loss': 0.08239847,
#  'Loss/regularization_loss': 0.14565885,
#  'Loss/total_loss': 0.34456635,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.090s
# I0921 04:11:34.420409 140011597215616 model_lib_v2.py:707] Step 2300 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.12893932,
#  'Loss/localization_loss': 0.046022482,
#  'Loss/regularization_loss': 0.14517176,
#  'Loss/total_loss': 0.32013357,
#  'learning_rate': 0.07986114}
# I0921 04:11:34.420925 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.12893932,
#  'Loss/localization_loss': 0.046022482,
#  'Loss/regularization_loss': 0.14517176,
#  'Loss/total_loss': 0.32013357,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.087s
# I0921 04:11:43.099835 140011597215616 model_lib_v2.py:707] Step 2400 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.23777243,
#  'Loss/localization_loss': 0.029104004,
#  'Loss/regularization_loss': 0.14472601,
#  'Loss/total_loss': 0.41160244,
#  'learning_rate': 0.07983897}
# I0921 04:11:43.100348 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.23777243,
#  'Loss/localization_loss': 0.029104004,
#  'Loss/regularization_loss': 0.14472601,
#  'Loss/total_loss': 0.41160244,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.090s
# I0921 04:11:52.075029 140011597215616 model_lib_v2.py:707] Step 2500 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.28265825,
#  'Loss/localization_loss': 0.090265945,
#  'Loss/regularization_loss': 0.14440645,
#  'Loss/total_loss': 0.51733065,
#  'learning_rate': 0.079815164}
# I0921 04:11:52.075419 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.28265825,
#  'Loss/localization_loss': 0.090265945,
#  'Loss/regularization_loss': 0.14440645,
#  'Loss/total_loss': 0.51733065,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.087s
# I0921 04:12:00.725617 140011597215616 model_lib_v2.py:707] Step 2600 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.29209763,
#  'Loss/localization_loss': 0.07037644,
#  'Loss/regularization_loss': 0.14408578,
#  'Loss/total_loss': 0.50655985,
#  'learning_rate': 0.07978972}
# I0921 04:12:00.726098 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.29209763,
#  'Loss/localization_loss': 0.07037644,
#  'Loss/regularization_loss': 0.14408578,
#  'Loss/total_loss': 0.50655985,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.092s
# I0921 04:12:09.929515 140011597215616 model_lib_v2.py:707] Step 2700 per-step time 0.092s
# INFO:tensorflow:{'Loss/classification_loss': 0.159874,
#  'Loss/localization_loss': 0.08438012,
#  'Loss/regularization_loss': 0.14378393,
#  'Loss/total_loss': 0.38803804,
#  'learning_rate': 0.07976264}
# I0921 04:12:09.930108 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.159874,
#  'Loss/localization_loss': 0.08438012,
#  'Loss/regularization_loss': 0.14378393,
#  'Loss/total_loss': 0.38803804,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.092s
# I0921 04:12:19.109409 140011597215616 model_lib_v2.py:707] Step 2800 per-step time 0.092s
# INFO:tensorflow:{'Loss/classification_loss': 0.21875012,
#  'Loss/localization_loss': 0.06737807,
#  'Loss/regularization_loss': 0.14337623,
#  'Loss/total_loss': 0.42950442,
#  'learning_rate': 0.07973392}
# I0921 04:12:19.109985 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.21875012,
#  'Loss/localization_loss': 0.06737807,
#  'Loss/regularization_loss': 0.14337623,
#  'Loss/total_loss': 0.42950442,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.090s
# I0921 04:12:28.083356 140011597215616 model_lib_v2.py:707] Step 2900 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.17793797,
#  'Loss/localization_loss': 0.033406213,
#  'Loss/regularization_loss': 0.14299563,
#  'Loss/total_loss': 0.3543398,
#  'learning_rate': 0.07970358}
# I0921 04:12:28.084099 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.17793797,
#  'Loss/localization_loss': 0.033406213,
#  'Loss/regularization_loss': 0.14299563,
#  'Loss/total_loss': 0.3543398,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.091s
# I0921 04:12:37.166365 140011597215616 model_lib_v2.py:707] Step 3000 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.179478,
#  'Loss/localization_loss': 0.06299484,
#  'Loss/regularization_loss': 0.14257503,
#  'Loss/total_loss': 0.38504785,
#  'learning_rate': 0.0796716}
# I0921 04:12:37.166821 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.179478,
#  'Loss/localization_loss': 0.06299484,
#  'Loss/regularization_loss': 0.14257503,
#  'Loss/total_loss': 0.38504785,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.101s
# I0921 04:12:47.223508 140011597215616 model_lib_v2.py:707] Step 3100 per-step time 0.101s
# INFO:tensorflow:{'Loss/classification_loss': 0.3165643,
#  'Loss/localization_loss': 0.039250337,
#  'Loss/regularization_loss': 0.14225352,
#  'Loss/total_loss': 0.49806815,
#  'learning_rate': 0.07963799}
# I0921 04:12:47.224051 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.3165643,
#  'Loss/localization_loss': 0.039250337,
#  'Loss/regularization_loss': 0.14225352,
#  'Loss/total_loss': 0.49806815,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.086s
# I0921 04:12:55.877934 140011597215616 model_lib_v2.py:707] Step 3200 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.17212632,
#  'Loss/localization_loss': 0.14826359,
#  'Loss/regularization_loss': 0.14191286,
#  'Loss/total_loss': 0.4623028,
#  'learning_rate': 0.07960275}
# I0921 04:12:55.878383 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.17212632,
#  'Loss/localization_loss': 0.14826359,
#  'Loss/regularization_loss': 0.14191286,
#  'Loss/total_loss': 0.4623028,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.089s
# I0921 04:13:04.747543 140011597215616 model_lib_v2.py:707] Step 3300 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.2670028,
#  'Loss/localization_loss': 0.07976362,
#  'Loss/regularization_loss': 0.1414554,
#  'Loss/total_loss': 0.48822182,
#  'learning_rate': 0.07956588}
# I0921 04:13:04.748035 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.2670028,
#  'Loss/localization_loss': 0.07976362,
#  'Loss/regularization_loss': 0.1414554,
#  'Loss/total_loss': 0.48822182,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.091s
# I0921 04:13:13.875726 140011597215616 model_lib_v2.py:707] Step 3400 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.15153031,
#  'Loss/localization_loss': 0.058293536,
#  'Loss/regularization_loss': 0.14116505,
#  'Loss/total_loss': 0.3509889,
#  'learning_rate': 0.079527386}
# I0921 04:13:13.876262 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.15153031,
#  'Loss/localization_loss': 0.058293536,
#  'Loss/regularization_loss': 0.14116505,
#  'Loss/total_loss': 0.3509889,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.086s
# I0921 04:13:22.453116 140011597215616 model_lib_v2.py:707] Step 3500 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.158542,
#  'Loss/localization_loss': 0.047157455,
#  'Loss/regularization_loss': 0.14083366,
#  'Loss/total_loss': 0.34653312,
#  'learning_rate': 0.07948727}
# I0921 04:13:22.453763 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.158542,
#  'Loss/localization_loss': 0.047157455,
#  'Loss/regularization_loss': 0.14083366,
#  'Loss/total_loss': 0.34653312,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.093s
# I0921 04:13:31.778331 140011597215616 model_lib_v2.py:707] Step 3600 per-step time 0.093s
# INFO:tensorflow:{'Loss/classification_loss': 0.16794184,
#  'Loss/localization_loss': 0.040175106,
#  'Loss/regularization_loss': 0.14062734,
#  'Loss/total_loss': 0.34874427,
#  'learning_rate': 0.079445526}
# I0921 04:13:31.778768 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.16794184,
#  'Loss/localization_loss': 0.040175106,
#  'Loss/regularization_loss': 0.14062734,
#  'Loss/total_loss': 0.34874427,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.087s
# I0921 04:13:40.452292 140011597215616 model_lib_v2.py:707] Step 3700 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.30319443,
#  'Loss/localization_loss': 0.11402619,
#  'Loss/regularization_loss': 0.14020145,
#  'Loss/total_loss': 0.55742204,
#  'learning_rate': 0.07940216}
# I0921 04:13:40.452670 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.30319443,
#  'Loss/localization_loss': 0.11402619,
#  'Loss/regularization_loss': 0.14020145,
#  'Loss/total_loss': 0.55742204,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.086s
# I0921 04:13:49.029277 140011597215616 model_lib_v2.py:707] Step 3800 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.14417045,
#  'Loss/localization_loss': 0.052981358,
#  'Loss/regularization_loss': 0.139802,
#  'Loss/total_loss': 0.33695382,
#  'learning_rate': 0.079357184}
# I0921 04:13:49.029838 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.14417045,
#  'Loss/localization_loss': 0.052981358,
#  'Loss/regularization_loss': 0.139802,
#  'Loss/total_loss': 0.33695382,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.088s
# I0921 04:13:57.818922 140011597215616 model_lib_v2.py:707] Step 3900 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.16490011,
#  'Loss/localization_loss': 0.07022538,
#  'Loss/regularization_loss': 0.13946103,
#  'Loss/total_loss': 0.37458652,
#  'learning_rate': 0.07931058}
# I0921 04:13:57.819436 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.16490011,
#  'Loss/localization_loss': 0.07022538,
#  'Loss/regularization_loss': 0.13946103,
#  'Loss/total_loss': 0.37458652,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.091s
# I0921 04:14:06.957140 140011597215616 model_lib_v2.py:707] Step 4000 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.22755222,
#  'Loss/localization_loss': 0.06670592,
#  'Loss/regularization_loss': 0.13902655,
#  'Loss/total_loss': 0.4332847,
#  'learning_rate': 0.07926236}
# I0921 04:14:06.957625 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.22755222,
#  'Loss/localization_loss': 0.06670592,
#  'Loss/regularization_loss': 0.13902655,
#  'Loss/total_loss': 0.4332847,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.098s
# I0921 04:14:16.762416 140011597215616 model_lib_v2.py:707] Step 4100 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.23251435,
#  'Loss/localization_loss': 0.07264994,
#  'Loss/regularization_loss': 0.13858852,
#  'Loss/total_loss': 0.4437528,
#  'learning_rate': 0.07921253}
# I0921 04:14:16.762882 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.23251435,
#  'Loss/localization_loss': 0.07264994,
#  'Loss/regularization_loss': 0.13858852,
#  'Loss/total_loss': 0.4437528,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.091s
# I0921 04:14:25.858715 140011597215616 model_lib_v2.py:707] Step 4200 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.19448994,
#  'Loss/localization_loss': 0.0326388,
#  'Loss/regularization_loss': 0.13837852,
#  'Loss/total_loss': 0.36550725,
#  'learning_rate': 0.07916109}
# I0921 04:14:25.859200 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.19448994,
#  'Loss/localization_loss': 0.0326388,
#  'Loss/regularization_loss': 0.13837852,
#  'Loss/total_loss': 0.36550725,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.087s
# I0921 04:14:34.519490 140011597215616 model_lib_v2.py:707] Step 4300 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.122576065,
#  'Loss/localization_loss': 0.026359247,
#  'Loss/regularization_loss': 0.13794817,
#  'Loss/total_loss': 0.28688347,
#  'learning_rate': 0.07910804}
# I0921 04:14:34.519995 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.122576065,
#  'Loss/localization_loss': 0.026359247,
#  'Loss/regularization_loss': 0.13794817,
#  'Loss/total_loss': 0.28688347,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.090s
# I0921 04:14:43.496182 140011597215616 model_lib_v2.py:707] Step 4400 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.23567952,
#  'Loss/localization_loss': 0.04764427,
#  'Loss/regularization_loss': 0.13737836,
#  'Loss/total_loss': 0.42070216,
#  'learning_rate': 0.07905338}
# I0921 04:14:43.496701 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.23567952,
#  'Loss/localization_loss': 0.04764427,
#  'Loss/regularization_loss': 0.13737836,
#  'Loss/total_loss': 0.42070216,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.089s
# I0921 04:14:52.420657 140011597215616 model_lib_v2.py:707] Step 4500 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.13987379,
#  'Loss/localization_loss': 0.022809839,
#  'Loss/regularization_loss': 0.13682798,
#  'Loss/total_loss': 0.2995116,
#  'learning_rate': 0.07899711}
# I0921 04:14:52.421067 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.13987379,
#  'Loss/localization_loss': 0.022809839,
#  'Loss/regularization_loss': 0.13682798,
#  'Loss/total_loss': 0.2995116,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.086s
# I0921 04:15:01.055218 140011597215616 model_lib_v2.py:707] Step 4600 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.15964466,
#  'Loss/localization_loss': 0.053485088,
#  'Loss/regularization_loss': 0.13629332,
#  'Loss/total_loss': 0.34942308,
#  'learning_rate': 0.078939244}
# I0921 04:15:01.055684 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.15964466,
#  'Loss/localization_loss': 0.053485088,
#  'Loss/regularization_loss': 0.13629332,
#  'Loss/total_loss': 0.34942308,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.088s
# I0921 04:15:09.858615 140011597215616 model_lib_v2.py:707] Step 4700 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.21755753,
#  'Loss/localization_loss': 0.04674937,
#  'Loss/regularization_loss': 0.1357544,
#  'Loss/total_loss': 0.4000613,
#  'learning_rate': 0.07887978}
# I0921 04:15:09.859117 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.21755753,
#  'Loss/localization_loss': 0.04674937,
#  'Loss/regularization_loss': 0.1357544,
#  'Loss/total_loss': 0.4000613,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.083s
# I0921 04:15:18.138347 140011597215616 model_lib_v2.py:707] Step 4800 per-step time 0.083s
# INFO:tensorflow:{'Loss/classification_loss': 0.15315077,
#  'Loss/localization_loss': 0.037153393,
#  'Loss/regularization_loss': 0.13531692,
#  'Loss/total_loss': 0.32562107,
#  'learning_rate': 0.07881871}
# I0921 04:15:18.138813 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.15315077,
#  'Loss/localization_loss': 0.037153393,
#  'Loss/regularization_loss': 0.13531692,
#  'Loss/total_loss': 0.32562107,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.089s
# I0921 04:15:27.012091 140011597215616 model_lib_v2.py:707] Step 4900 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.09264086,
#  'Loss/localization_loss': 0.036163907,
#  'Loss/regularization_loss': 0.13478087,
#  'Loss/total_loss': 0.26358563,
#  'learning_rate': 0.07875605}
# I0921 04:15:27.012570 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.09264086,
#  'Loss/localization_loss': 0.036163907,
#  'Loss/regularization_loss': 0.13478087,
#  'Loss/total_loss': 0.26358563,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.092s
# I0921 04:15:36.245002 140011597215616 model_lib_v2.py:707] Step 5000 per-step time 0.092s
# INFO:tensorflow:{'Loss/classification_loss': 0.07938814,
#  'Loss/localization_loss': 0.041894604,
#  'Loss/regularization_loss': 0.13431475,
#  'Loss/total_loss': 0.25559747,
#  'learning_rate': 0.078691795}
# I0921 04:15:36.245481 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.07938814,
#  'Loss/localization_loss': 0.041894604,
#  'Loss/regularization_loss': 0.13431475,
#  'Loss/total_loss': 0.25559747,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.101s
# I0921 04:15:46.304268 140011597215616 model_lib_v2.py:707] Step 5100 per-step time 0.101s
# INFO:tensorflow:{'Loss/classification_loss': 0.28051212,
#  'Loss/localization_loss': 0.05462263,
#  'Loss/regularization_loss': 0.13380595,
#  'Loss/total_loss': 0.46894068,
#  'learning_rate': 0.07862595}
# I0921 04:15:46.304741 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.28051212,
#  'Loss/localization_loss': 0.05462263,
#  'Loss/regularization_loss': 0.13380595,
#  'Loss/total_loss': 0.46894068,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.090s
# I0921 04:15:55.275940 140011597215616 model_lib_v2.py:707] Step 5200 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.1528874,
#  'Loss/localization_loss': 0.05146856,
#  'Loss/regularization_loss': 0.1333245,
#  'Loss/total_loss': 0.33768046,
#  'learning_rate': 0.07855851}
# I0921 04:15:55.276624 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.1528874,
#  'Loss/localization_loss': 0.05146856,
#  'Loss/regularization_loss': 0.1333245,
#  'Loss/total_loss': 0.33768046,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.089s
# I0921 04:16:04.207049 140011597215616 model_lib_v2.py:707] Step 5300 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.04840072,
#  'Loss/localization_loss': 0.035157297,
#  'Loss/regularization_loss': 0.1327899,
#  'Loss/total_loss': 0.2163479,
#  'learning_rate': 0.07848949}
# I0921 04:16:04.207509 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.04840072,
#  'Loss/localization_loss': 0.035157297,
#  'Loss/regularization_loss': 0.1327899,
#  'Loss/total_loss': 0.2163479,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.092s
# I0921 04:16:13.444801 140011597215616 model_lib_v2.py:707] Step 5400 per-step time 0.092s
# INFO:tensorflow:{'Loss/classification_loss': 0.09755746,
#  'Loss/localization_loss': 0.044391837,
#  'Loss/regularization_loss': 0.13223852,
#  'Loss/total_loss': 0.2741878,
#  'learning_rate': 0.078418896}
# I0921 04:16:13.445280 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.09755746,
#  'Loss/localization_loss': 0.044391837,
#  'Loss/regularization_loss': 0.13223852,
#  'Loss/total_loss': 0.2741878,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.086s
# I0921 04:16:22.062103 140011597215616 model_lib_v2.py:707] Step 5500 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.08868968,
#  'Loss/localization_loss': 0.032514878,
#  'Loss/regularization_loss': 0.13168311,
#  'Loss/total_loss': 0.25288767,
#  'learning_rate': 0.078346714}
# I0921 04:16:22.063313 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.08868968,
#  'Loss/localization_loss': 0.032514878,
#  'Loss/regularization_loss': 0.13168311,
#  'Loss/total_loss': 0.25288767,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.090s
# I0921 04:16:31.066351 140011597215616 model_lib_v2.py:707] Step 5600 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.091543294,
#  'Loss/localization_loss': 0.03915356,
#  'Loss/regularization_loss': 0.13115825,
#  'Loss/total_loss': 0.26185513,
#  'learning_rate': 0.07827295}
# I0921 04:16:31.066906 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.091543294,
#  'Loss/localization_loss': 0.03915356,
#  'Loss/regularization_loss': 0.13115825,
#  'Loss/total_loss': 0.26185513,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.090s
# I0921 04:16:40.083209 140011597215616 model_lib_v2.py:707] Step 5700 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.20482011,
#  'Loss/localization_loss': 0.051213834,
#  'Loss/regularization_loss': 0.13070421,
#  'Loss/total_loss': 0.38673818,
#  'learning_rate': 0.07819763}
# I0921 04:16:40.083730 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.20482011,
#  'Loss/localization_loss': 0.051213834,
#  'Loss/regularization_loss': 0.13070421,
#  'Loss/total_loss': 0.38673818,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.088s
# I0921 04:16:48.868229 140011597215616 model_lib_v2.py:707] Step 5800 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.1246263,
#  'Loss/localization_loss': 0.037398607,
#  'Loss/regularization_loss': 0.13016535,
#  'Loss/total_loss': 0.29219025,
#  'learning_rate': 0.07812072}
# I0921 04:16:48.868713 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.1246263,
#  'Loss/localization_loss': 0.037398607,
#  'Loss/regularization_loss': 0.13016535,
#  'Loss/total_loss': 0.29219025,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.091s
# I0921 04:16:57.926640 140011597215616 model_lib_v2.py:707] Step 5900 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.217156,
#  'Loss/localization_loss': 0.03897453,
#  'Loss/regularization_loss': 0.12960845,
#  'Loss/total_loss': 0.38573897,
#  'learning_rate': 0.078042254}
# I0921 04:16:57.927004 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.217156,
#  'Loss/localization_loss': 0.03897453,
#  'Loss/regularization_loss': 0.12960845,
#  'Loss/total_loss': 0.38573897,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.087s
# I0921 04:17:06.646323 140011597215616 model_lib_v2.py:707] Step 6000 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.12000466,
#  'Loss/localization_loss': 0.052397586,
#  'Loss/regularization_loss': 0.1290855,
#  'Loss/total_loss': 0.30148774,
#  'learning_rate': 0.07796223}
# I0921 04:17:06.646850 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.12000466,
#  'Loss/localization_loss': 0.052397586,
#  'Loss/regularization_loss': 0.1290855,
#  'Loss/total_loss': 0.30148774,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 0.097s
# I0921 04:17:16.311428 140011597215616 model_lib_v2.py:707] Step 6100 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.11951716,
#  'Loss/localization_loss': 0.051000413,
#  'Loss/regularization_loss': 0.12866679,
#  'Loss/total_loss': 0.29918438,
#  'learning_rate': 0.077880636}
# I0921 04:17:16.311996 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.11951716,
#  'Loss/localization_loss': 0.051000413,
#  'Loss/regularization_loss': 0.12866679,
#  'Loss/total_loss': 0.29918438,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.090s
# I0921 04:17:25.299280 140011597215616 model_lib_v2.py:707] Step 6200 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.09672693,
#  'Loss/localization_loss': 0.06630788,
#  'Loss/regularization_loss': 0.1281863,
#  'Loss/total_loss': 0.2912211,
#  'learning_rate': 0.07779749}
# I0921 04:17:25.299781 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.09672693,
#  'Loss/localization_loss': 0.06630788,
#  'Loss/regularization_loss': 0.1281863,
#  'Loss/total_loss': 0.2912211,
#  'learning_rate': 0.07779749}
# INFO:tensorflow:Step 6300 per-step time 0.085s
# I0921 04:17:33.816461 140011597215616 model_lib_v2.py:707] Step 6300 per-step time 0.085s
# INFO:tensorflow:{'Loss/classification_loss': 0.103265464,
#  'Loss/localization_loss': 0.042966597,
#  'Loss/regularization_loss': 0.12776923,
#  'Loss/total_loss': 0.2740013,
#  'learning_rate': 0.07771279}
# I0921 04:17:33.816978 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.103265464,
#  'Loss/localization_loss': 0.042966597,
#  'Loss/regularization_loss': 0.12776923,
#  'Loss/total_loss': 0.2740013,
#  'learning_rate': 0.07771279}
# INFO:tensorflow:Step 6400 per-step time 0.086s
# I0921 04:17:42.383996 140011597215616 model_lib_v2.py:707] Step 6400 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.14822577,
#  'Loss/localization_loss': 0.045636598,
#  'Loss/regularization_loss': 0.12733366,
#  'Loss/total_loss': 0.32119602,
#  'learning_rate': 0.077626534}
# I0921 04:17:42.384488 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.14822577,
#  'Loss/localization_loss': 0.045636598,
#  'Loss/regularization_loss': 0.12733366,
#  'Loss/total_loss': 0.32119602,
# ...
#  'Loss/localization_loss': 0.035109255,
#  'Loss/regularization_loss': 0.06575725,
#  'Loss/total_loss': 0.166174,
#  'learning_rate': 0.03539402}
# INFO:tensorflow:Step 27400 per-step time 0.088s
# I0921 04:49:07.035471 140011597215616 model_lib_v2.py:707] Step 27400 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.06335924,
#  'Loss/localization_loss': 0.017317584,
#  'Loss/regularization_loss': 0.06561978,
#  'Loss/total_loss': 0.1462966,
#  'learning_rate': 0.035139363}
# I0921 04:49:07.035978 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.06335924,
#  'Loss/localization_loss': 0.017317584,
#  'Loss/regularization_loss': 0.06561978,
#  'Loss/total_loss': 0.1462966,
#  'learning_rate': 0.035139363}
# INFO:tensorflow:Step 27500 per-step time 0.088s
# I0921 04:49:15.814868 140011597215616 model_lib_v2.py:707] Step 27500 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.059113145,
#  'Loss/localization_loss': 0.009688465,
#  'Loss/regularization_loss': 0.06547407,
#  'Loss/total_loss': 0.13427567,
#  'learning_rate': 0.03488491}
# I0921 04:49:15.815365 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.059113145,
#  'Loss/localization_loss': 0.009688465,
#  'Loss/regularization_loss': 0.06547407,
#  'Loss/total_loss': 0.13427567,
#  'learning_rate': 0.03488491}
# INFO:tensorflow:Step 27600 per-step time 0.091s
# I0921 04:49:24.881622 140011597215616 model_lib_v2.py:707] Step 27600 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.028990712,
#  'Loss/localization_loss': 0.008882744,
#  'Loss/regularization_loss': 0.065334626,
#  'Loss/total_loss': 0.10320808,
#  'learning_rate': 0.034630664}
# I0921 04:49:24.881992 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.028990712,
#  'Loss/localization_loss': 0.008882744,
#  'Loss/regularization_loss': 0.065334626,
#  'Loss/total_loss': 0.10320808,
#  'learning_rate': 0.034630664}
# INFO:tensorflow:Step 27700 per-step time 0.090s
# I0921 04:49:33.891836 140011597215616 model_lib_v2.py:707] Step 27700 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.05633067,
#  'Loss/localization_loss': 0.007997708,
#  'Loss/regularization_loss': 0.06518859,
#  'Loss/total_loss': 0.12951696,
#  'learning_rate': 0.034376644}
# I0921 04:49:33.892146 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.05633067,
#  'Loss/localization_loss': 0.007997708,
#  'Loss/regularization_loss': 0.06518859,
#  'Loss/total_loss': 0.12951696,
#  'learning_rate': 0.034376644}
# INFO:tensorflow:Step 27800 per-step time 0.086s
# I0921 04:49:42.519031 140011597215616 model_lib_v2.py:707] Step 27800 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.03768791,
#  'Loss/localization_loss': 0.009130024,
#  'Loss/regularization_loss': 0.065044984,
#  'Loss/total_loss': 0.11186291,
#  'learning_rate': 0.034122847}
# I0921 04:49:42.519527 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.03768791,
#  'Loss/localization_loss': 0.009130024,
#  'Loss/regularization_loss': 0.065044984,
#  'Loss/total_loss': 0.11186291,
#  'learning_rate': 0.034122847}
# INFO:tensorflow:Step 27900 per-step time 0.089s
# I0921 04:49:51.398164 140011597215616 model_lib_v2.py:707] Step 27900 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.08198275,
#  'Loss/localization_loss': 0.008171591,
#  'Loss/regularization_loss': 0.064900555,
#  'Loss/total_loss': 0.1550549,
#  'learning_rate': 0.0338693}
# I0921 04:49:51.398652 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.08198275,
#  'Loss/localization_loss': 0.008171591,
#  'Loss/regularization_loss': 0.064900555,
#  'Loss/total_loss': 0.1550549,
#  'learning_rate': 0.0338693}
# INFO:tensorflow:Step 28000 per-step time 0.083s
# I0921 04:49:59.735353 140011597215616 model_lib_v2.py:707] Step 28000 per-step time 0.083s
# INFO:tensorflow:{'Loss/classification_loss': 0.03739095,
#  'Loss/localization_loss': 0.005923339,
#  'Loss/regularization_loss': 0.06475499,
#  'Loss/total_loss': 0.108069286,
#  'learning_rate': 0.033615995}
# I0921 04:49:59.735879 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.03739095,
#  'Loss/localization_loss': 0.005923339,
#  'Loss/regularization_loss': 0.06475499,
#  'Loss/total_loss': 0.108069286,
#  'learning_rate': 0.033615995}
# INFO:tensorflow:Step 28100 per-step time 0.103s
# I0921 04:50:10.010545 140011597215616 model_lib_v2.py:707] Step 28100 per-step time 0.103s
# INFO:tensorflow:{'Loss/classification_loss': 0.040247697,
#  'Loss/localization_loss': 0.0061168554,
#  'Loss/regularization_loss': 0.06461367,
#  'Loss/total_loss': 0.11097822,
#  'learning_rate': 0.033362966}
# I0921 04:50:10.011032 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.040247697,
#  'Loss/localization_loss': 0.0061168554,
#  'Loss/regularization_loss': 0.06461367,
#  'Loss/total_loss': 0.11097822,
#  'learning_rate': 0.033362966}
# INFO:tensorflow:Step 28200 per-step time 0.086s
# I0921 04:50:18.603662 140011597215616 model_lib_v2.py:707] Step 28200 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.08669343,
#  'Loss/localization_loss': 0.0076335957,
#  'Loss/regularization_loss': 0.06447545,
#  'Loss/total_loss': 0.15880248,
#  'learning_rate': 0.033110205}
# I0921 04:50:18.604157 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.08669343,
#  'Loss/localization_loss': 0.0076335957,
#  'Loss/regularization_loss': 0.06447545,
#  'Loss/total_loss': 0.15880248,
#  'learning_rate': 0.033110205}
# INFO:tensorflow:Step 28300 per-step time 0.088s
# I0921 04:50:27.373491 140011597215616 model_lib_v2.py:707] Step 28300 per-step time 0.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.05370327,
#  'Loss/localization_loss': 0.017639978,
#  'Loss/regularization_loss': 0.06434044,
#  'Loss/total_loss': 0.13568369,
#  'learning_rate': 0.032857716}
# I0921 04:50:27.373982 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.05370327,
#  'Loss/localization_loss': 0.017639978,
#  'Loss/regularization_loss': 0.06434044,
#  'Loss/total_loss': 0.13568369,
#  'learning_rate': 0.032857716}
# INFO:tensorflow:Step 28400 per-step time 0.085s
# I0921 04:50:35.906847 140011597215616 model_lib_v2.py:707] Step 28400 per-step time 0.085s
# INFO:tensorflow:{'Loss/classification_loss': 0.040682986,
#  'Loss/localization_loss': 0.015680054,
#  'Loss/regularization_loss': 0.064204186,
#  'Loss/total_loss': 0.120567225,
#  'learning_rate': 0.032605536}
# I0921 04:50:35.907408 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.040682986,
#  'Loss/localization_loss': 0.015680054,
#  'Loss/regularization_loss': 0.064204186,
#  'Loss/total_loss': 0.120567225,
#  'learning_rate': 0.032605536}
# INFO:tensorflow:Step 28500 per-step time 0.087s
# I0921 04:50:44.658570 140011597215616 model_lib_v2.py:707] Step 28500 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.04371727,
#  'Loss/localization_loss': 0.007692425,
#  'Loss/regularization_loss': 0.06407169,
#  'Loss/total_loss': 0.11548139,
#  'learning_rate': 0.032353655}
# I0921 04:50:44.659051 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.04371727,
#  'Loss/localization_loss': 0.007692425,
#  'Loss/regularization_loss': 0.06407169,
#  'Loss/total_loss': 0.11548139,
#  'learning_rate': 0.032353655}
# INFO:tensorflow:Step 28600 per-step time 0.087s
# I0921 04:50:53.329371 140011597215616 model_lib_v2.py:707] Step 28600 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.04985722,
#  'Loss/localization_loss': 0.014802875,
#  'Loss/regularization_loss': 0.0639453,
#  'Loss/total_loss': 0.1286054,
#  'learning_rate': 0.032102082}
# I0921 04:50:53.329855 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.04985722,
#  'Loss/localization_loss': 0.014802875,
#  'Loss/regularization_loss': 0.0639453,
#  'Loss/total_loss': 0.1286054,
#  'learning_rate': 0.032102082}
# INFO:tensorflow:Step 28700 per-step time 0.089s
# I0921 04:51:02.262738 140011597215616 model_lib_v2.py:707] Step 28700 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.047969494,
#  'Loss/localization_loss': 0.008969177,
#  'Loss/regularization_loss': 0.06381546,
#  'Loss/total_loss': 0.12075413,
#  'learning_rate': 0.03185084}
# I0921 04:51:02.263281 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.047969494,
#  'Loss/localization_loss': 0.008969177,
#  'Loss/regularization_loss': 0.06381546,
#  'Loss/total_loss': 0.12075413,
#  'learning_rate': 0.03185084}
# INFO:tensorflow:Step 28800 per-step time 0.091s
# I0921 04:51:11.311993 140011597215616 model_lib_v2.py:707] Step 28800 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.06690624,
#  'Loss/localization_loss': 0.014310961,
#  'Loss/regularization_loss': 0.06368811,
#  'Loss/total_loss': 0.14490531,
#  'learning_rate': 0.031599928}
# I0921 04:51:11.312661 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.06690624,
#  'Loss/localization_loss': 0.014310961,
#  'Loss/regularization_loss': 0.06368811,
#  'Loss/total_loss': 0.14490531,
#  'learning_rate': 0.031599928}
# INFO:tensorflow:Step 28900 per-step time 0.087s
# I0921 04:51:20.056734 140011597215616 model_lib_v2.py:707] Step 28900 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.04593944,
#  'Loss/localization_loss': 0.01197327,
#  'Loss/regularization_loss': 0.06355926,
#  'Loss/total_loss': 0.12147197,
#  'learning_rate': 0.03134937}
# I0921 04:51:20.057235 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.04593944,
#  'Loss/localization_loss': 0.01197327,
#  'Loss/regularization_loss': 0.06355926,
#  'Loss/total_loss': 0.12147197,
#  'learning_rate': 0.03134937}
# INFO:tensorflow:Step 29000 per-step time 0.097s
# I0921 04:51:29.692276 140011597215616 model_lib_v2.py:707] Step 29000 per-step time 0.097s
# INFO:tensorflow:{'Loss/classification_loss': 0.045050036,
#  'Loss/localization_loss': 0.006527462,
#  'Loss/regularization_loss': 0.06343459,
#  'Loss/total_loss': 0.115012094,
#  'learning_rate': 0.031099161}
# I0921 04:51:29.692703 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.045050036,
#  'Loss/localization_loss': 0.006527462,
#  'Loss/regularization_loss': 0.06343459,
#  'Loss/total_loss': 0.115012094,
#  'learning_rate': 0.031099161}
# INFO:tensorflow:Step 29100 per-step time 0.098s
# I0921 04:51:39.520466 140011597215616 model_lib_v2.py:707] Step 29100 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.053735178,
#  'Loss/localization_loss': 0.010664335,
#  'Loss/regularization_loss': 0.06330473,
#  'Loss/total_loss': 0.12770423,
#  'learning_rate': 0.030849317}
# I0921 04:51:39.520987 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.053735178,
#  'Loss/localization_loss': 0.010664335,
#  'Loss/regularization_loss': 0.06330473,
#  'Loss/total_loss': 0.12770423,
#  'learning_rate': 0.030849317}
# INFO:tensorflow:Step 29200 per-step time 0.086s
# I0921 04:51:48.098695 140011597215616 model_lib_v2.py:707] Step 29200 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.054713055,
#  'Loss/localization_loss': 0.013531722,
#  'Loss/regularization_loss': 0.0631724,
#  'Loss/total_loss': 0.13141719,
#  'learning_rate': 0.030599851}
# I0921 04:51:48.099195 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.054713055,
#  'Loss/localization_loss': 0.013531722,
#  'Loss/regularization_loss': 0.0631724,
#  'Loss/total_loss': 0.13141719,
#  'learning_rate': 0.030599851}
# INFO:tensorflow:Step 29300 per-step time 0.087s
# I0921 04:51:56.815969 140011597215616 model_lib_v2.py:707] Step 29300 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.077343985,
#  'Loss/localization_loss': 0.025278954,
#  'Loss/regularization_loss': 0.0630434,
#  'Loss/total_loss': 0.16566634,
#  'learning_rate': 0.03035077}
# I0921 04:51:56.816468 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.077343985,
#  'Loss/localization_loss': 0.025278954,
#  'Loss/regularization_loss': 0.0630434,
#  'Loss/total_loss': 0.16566634,
#  'learning_rate': 0.03035077}
# INFO:tensorflow:Step 29400 per-step time 0.093s
# I0921 04:52:06.054726 140011597215616 model_lib_v2.py:707] Step 29400 per-step time 0.093s
# INFO:tensorflow:{'Loss/classification_loss': 0.054877345,
#  'Loss/localization_loss': 0.020133138,
#  'Loss/regularization_loss': 0.06291966,
#  'Loss/total_loss': 0.13793014,
#  'learning_rate': 0.03010209}
# I0921 04:52:06.055189 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.054877345,
#  'Loss/localization_loss': 0.020133138,
#  'Loss/regularization_loss': 0.06291966,
#  'Loss/total_loss': 0.13793014,
#  'learning_rate': 0.03010209}
# INFO:tensorflow:Step 29500 per-step time 0.090s
# I0921 04:52:15.051923 140011597215616 model_lib_v2.py:707] Step 29500 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.060467817,
#  'Loss/localization_loss': 0.0076846955,
#  'Loss/regularization_loss': 0.062797055,
#  'Loss/total_loss': 0.13094956,
#  'learning_rate': 0.029853815}
# I0921 04:52:15.052431 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.060467817,
#  'Loss/localization_loss': 0.0076846955,
#  'Loss/regularization_loss': 0.062797055,
#  'Loss/total_loss': 0.13094956,
#  'learning_rate': 0.029853815}
# INFO:tensorflow:Step 29600 per-step time 0.089s
# I0921 04:52:23.909395 140011597215616 model_lib_v2.py:707] Step 29600 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.11190196,
#  'Loss/localization_loss': 0.015976952,
#  'Loss/regularization_loss': 0.06267483,
#  'Loss/total_loss': 0.19055375,
#  'learning_rate': 0.029605953}
# I0921 04:52:23.909900 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.11190196,
#  'Loss/localization_loss': 0.015976952,
#  'Loss/regularization_loss': 0.06267483,
#  'Loss/total_loss': 0.19055375,
#  'learning_rate': 0.029605953}
# INFO:tensorflow:Step 29700 per-step time 0.087s
# I0921 04:52:32.609561 140011597215616 model_lib_v2.py:707] Step 29700 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.06188907,
#  'Loss/localization_loss': 0.018689375,
#  'Loss/regularization_loss': 0.062552206,
#  'Loss/total_loss': 0.14313066,
#  'learning_rate': 0.029358525}
# I0921 04:52:32.610066 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.06188907,
#  'Loss/localization_loss': 0.018689375,
#  'Loss/regularization_loss': 0.062552206,
#  'Loss/total_loss': 0.14313066,
#  'learning_rate': 0.029358525}
# INFO:tensorflow:Step 29800 per-step time 0.086s
# I0921 04:52:41.218272 140011597215616 model_lib_v2.py:707] Step 29800 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.11658117,
#  'Loss/localization_loss': 0.01700164,
#  'Loss/regularization_loss': 0.062441073,
#  'Loss/total_loss': 0.19602388,
#  'learning_rate': 0.029111534}
# I0921 04:52:41.218852 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.11658117,
#  'Loss/localization_loss': 0.01700164,
#  'Loss/regularization_loss': 0.062441073,
#  'Loss/total_loss': 0.19602388,
#  'learning_rate': 0.029111534}
# INFO:tensorflow:Step 29900 per-step time 0.087s
# I0921 04:52:49.907016 140011597215616 model_lib_v2.py:707] Step 29900 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.035108443,
#  'Loss/localization_loss': 0.0071842535,
#  'Loss/regularization_loss': 0.06232332,
#  'Loss/total_loss': 0.104616016,
#  'learning_rate': 0.028864983}
# I0921 04:52:49.907450 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.035108443,
#  'Loss/localization_loss': 0.0071842535,
#  'Loss/regularization_loss': 0.06232332,
#  'Loss/total_loss': 0.104616016,
#  'learning_rate': 0.028864983}
# INFO:tensorflow:Step 30000 per-step time 0.089s
# I0921 04:52:58.847066 140011597215616 model_lib_v2.py:707] Step 30000 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.029306147,
#  'Loss/localization_loss': 0.009205058,
#  'Loss/regularization_loss': 0.062208,
#  'Loss/total_loss': 0.100719206,
#  'learning_rate': 0.028618898}
# I0921 04:52:58.847537 140011597215616 model_lib_v2.py:708] {'Loss/classification_loss': 0.029306147,
#  'Loss/localization_loss': 0.009205058,
#  'Loss/regularization_loss': 0.062208,
#  'Loss/total_loss': 0.100719206,
#  'learning_rate': 0.028618898}

# %%
training_files['PIPELINE_CONFIG']
# Out:
# 'Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config'

# %%
import tensorflow as tf
tf.version.VERSION
# Out:
# '2.9.0'

# %%
# with open('/usr/local/lib/python3.7/dist-packages/official/modeling/optimization/optimizer_factory.py', 'r') as f:
    # print(f.read())

# %% [markdown]
# # (Optional) Model evaluation

# %%
# # stop evaluation if needed
# command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])
# !{command}

# %% [markdown]
# # Predicting object category in image
#
# ### Load trained model from checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(training_files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], check_point)).expect_partial()

# @tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %%
paths['CHECKPOINT_PATH']
# Out:
# 'Tensorflow/workspace/models/my_ssd_mobnet'

# %% [markdown]
# ### Detect objects in image

# %%
import cv2 
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 10]

# Randomly select an image to be detected
# tmp_img = random.choice([file for file in os.listdir(os.path.join(paths['IMAGE_PATH'], 
#                                               'test')) if file.endswith(".JPG")])
# IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', tmp_img)
tmp_img = random.choice([file for file in os.listdir(os.path.join(paths['IMAGE_PATH'], 
                                              'train')) if file.endswith(".png")])
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'train', tmp_img)
IMAGE_PATH = './crackers_100-199g_H_1.jpg'

category_index = label_map_util.create_category_index_from_labelmap(training_files['LABELMAP'])

img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=2,
            min_score_thresh=.7,
            agnostic_mode=False,
            line_thickness=8)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
print("detected class:")
print(category_index[detections['detection_classes'][0]+label_id_offset]['name'])
print("detected probability")
print(detections['detection_scores'][0])
print("true class")
print(IMAGE_PATH)
# Out:
# detected class:
# crackers_300g-399g
# detected probability
# 0.7014786
# true class
# ./crackers_300-399g_H_3.jpg

# %%
# !zip -r Tensorflow.zip Tensorflow/
from google.colab import files
files.download("/content/Tensorflow.zip")
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_48.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a94.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_12.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a29.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_35.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_65.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a14.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a81.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a87.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_a9.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_b4.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a23.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a98.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_2.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_500g-599g_a2.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_c8.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a67.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_79.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_71.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a34.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a15.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_300g-399g_a4.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a49.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_300g-399g_a7.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_50.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a26.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a34.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_400g-499g_c1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a3.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_300g-399g_a5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_63.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a23.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_400g-499g_a2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a54.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a16.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_17.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a88.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a15.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_20.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_11.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_30.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_20.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a7.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_61.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_23.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a3.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a24.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_b10.xml (deflated 48%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_33.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a80.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a15.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_b1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_59.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_60.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a12.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a31.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_300g-399g_a2.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a81.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a8.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_b4.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a13.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_24.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a10.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_18.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a25.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_500g-599g_b1.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a6.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_4.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a47.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_c2.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_33.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a19.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_14.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a75.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a15.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_b1.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_a5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a21.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a6.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_8.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a19.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_25.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a73.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a84.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_16.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_31.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a3.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_30.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_3.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_33.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a60.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_17.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_b2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_a9.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_a65.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a84.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_b6.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/crackers_1g-99g_a2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a22.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_7.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_63.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a26.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_52.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a15.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/halal_a45.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_59.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_b3.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_a3.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_62.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_6.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_58.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a4.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_26.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_37.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a6.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a97.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_52.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_a7.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a90.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a46.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_c1.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a11.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_29.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a18.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a40.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_a56.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a7.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_49.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_69.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_31.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a41.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a30.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_b6.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a12.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_b1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a10.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a28.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_73.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_59.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a6.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a21.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_500g-599g_b1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a20.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a69.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_7.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_a5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a66.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_79.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a28.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_11.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_43.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a45.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a21.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_c1.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/halal_c5.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/halal_a65.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a85.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_60.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a29.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a16.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a63.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_400g-499g_a5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_19.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a18.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_32.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_17.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a10.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a1.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a31.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a77.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_a12.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_8.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_61.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_b1.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a77.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a73.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a79.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_600g-699g_a5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_57.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a26.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a23.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a20.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a16.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a12.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a71.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a61.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_300g-399g_b1.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/halal_a49.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_31.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_50.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_8.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_18.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_c2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a13.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a39.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a4.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_25.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_a3.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_14.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a27.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_a11.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_22.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_b9.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a1.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a10.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_71.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_a50.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a34.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_22.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_c2.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a7.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a21.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_29.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_19.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_c2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a49.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a21.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_10.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a36.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/halal_a21.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_10.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a12.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a5.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_38.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_a6.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_b13.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_28.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_25.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a15.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a78.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a20.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_23.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_50.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_45.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_46.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_b2.xml (deflated 48%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_18.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a12.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a41.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_8.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_512.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a12.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_6.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_63.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a44.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a94.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a27.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_57.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_40.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a16.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_49.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a53.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_3.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_13.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a5.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a38.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a4.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_c15.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a28.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_60.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_b2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a20.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a63.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a54.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_a5.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a37.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_32.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_400g-499g_a3.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a48.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a11.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_54.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a26.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a12.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_600g-699g_c1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_b3.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_c2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_c1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_600g-699g_a4.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a3.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_22.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_56.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_c1.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a35.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_14.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a64.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_41.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_6.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_20.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_41.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_48.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_50.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_a1.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_11.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_b4.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a55.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/halal_c9.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a33.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_21.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a24.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a31.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a14.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a15.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_c14.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_c1.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_66.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_b1.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_b2.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/halal_a82.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_b5.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_64.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_44.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_53.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_a6.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a19.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_c10.xml (deflated 48%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a11.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a17.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_49.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a13.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a29.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a63.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a25.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_35.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_11.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_17.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_b7.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a80.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_600g-699g_a5.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a11.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_28.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_c1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a11.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a48.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_a80.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_76.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_21.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a7.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_c14.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_42.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_b1.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_46.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a8.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a28.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a12.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_8.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a62.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a11.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_a6.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_6.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a39.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/halal_b1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a5.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_c15.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_11.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a56.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_b2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_300g-399g_b2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_b1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a15.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_b1.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a70.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_1g-99g_a5.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a6.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_61.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_c3.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a18.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_34.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a76.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_b5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_c9.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_1.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_54.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a86.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_b8.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a12.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_b12.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_a1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_29.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_7.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a32.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a31.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_b6.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_1g-99g_a2.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a32.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_31.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_62.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_23.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a6.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_600g-699g_a1.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_57.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_28.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_7.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a96.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a22.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_b1.xml (deflated 49%)
#   adding: Tensorflow/workspace/images/train/cookies_400g-499g_a4.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_62.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a13.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_4.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a30.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a76.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a6.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_31.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_42.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_c1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a64.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_b2.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_29.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a61.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a8.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_b5.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a38.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_300g-399g_b2.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/halal_a42.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_7.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a55.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_14.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_68.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_15.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_12.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_55.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_27.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_b1.xml (deflated 48%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_b5.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a3.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a3.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a4.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_72.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_b3.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a52.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a13.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a11.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_b3.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a57.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_63.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a1.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_1g-99g_a4.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a43.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_17.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_a33.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a51.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a81.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a99.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_35.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_5.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_46.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a22.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a1.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a79.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a30.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_27.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_26.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a87.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_77.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a85.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a46.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_a7.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a65.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_43.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_41.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_26.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a3.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a10.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a10.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a13.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_c5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a23.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a79.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/halal_a25.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_8.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_30.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_31.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a14.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a23.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_500g-599g_a1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a23.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a4.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_c1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_66.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_9.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_13.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_c16.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a28.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a50.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_58.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a29.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_a1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_55.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_a22.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_c6.xml (deflated 48%)
#   adding: Tensorflow/workspace/images/train/halal_a47.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_47.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_4.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a16.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_7.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a3.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_59.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a43.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a90.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_28.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_51.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a75.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a49.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a69.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a2.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/halal_a45.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_2.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_42.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_14.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_36.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_a27.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a18.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_79.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_b12.xml (deflated 48%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_c3.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a2.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_45.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_64.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_a2.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_5.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_c10.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a58.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_32.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_27.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_b1.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_45.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_b11.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a4.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/Baked beans_400-499g_28.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_400g-499g_10.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_12.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a60.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a27.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_1g-99g_a1.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_34.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a14.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/sardines_400g-499g_2.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_400g-499g_c1.xml (deflated 50%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a56.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/sardines_100g-199g_a8.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_400g-499g_a5.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_1g-99g_54.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_800g-899g_a5.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/halal_73.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_1kg-1.99kg_44.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_300g-399g_a14.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a27.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_15.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_a7.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_27.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_61.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a23.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_16.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_100g-199g_a20.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a6.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a23.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_300g-399g_b1.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a42.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_a91.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a5.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/halal_a60.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_a8.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_c8.xml (deflated 48%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_b7.png (deflated 0%)
#   adding: Tensorflow/workspace/images/train/cookies_200g-299g_66.xml (deflated 51%)
#   adding: Tensorflow/workspace/images/train/halal_24.xml (deflated 47%)
#   adding: Tensorflow/workspace/images/train/crackers_100g-199g_51.xml (deflated 52%)
#   adding: Tensorflow/workspace/images/train/crackers_200g-299g_25.xml (deflated 52%)
# ...
#   adding: Tensorflow/models/research/deeplab/g3doc/quantize.md (deflated 63%)
#   adding: Tensorflow/models/research/deeplab/g3doc/export_model.md (deflated 48%)
#   adding: Tensorflow/models/research/deeplab/g3doc/cityscapes.md (deflated 67%)
#   adding: Tensorflow/models/research/deeplab/model.py (deflated 78%)
#   adding: Tensorflow/models/research/deeplab/testing/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/testing/info.md (deflated 35%)
#   adding: Tensorflow/models/research/deeplab/testing/pascal_voc_seg/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/testing/pascal_voc_seg/val-00000-of-00001.tfrecord (deflated 0%)
#   adding: Tensorflow/models/research/deeplab/common.py (deflated 69%)
#   adding: Tensorflow/models/research/deeplab/core/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/core/preprocess_utils_test.py (deflated 85%)
#   adding: Tensorflow/models/research/deeplab/core/feature_extractor.py (deflated 79%)
#   adding: Tensorflow/models/research/deeplab/core/dense_prediction_cell.py (deflated 72%)
#   adding: Tensorflow/models/research/deeplab/core/nas_network.py (deflated 73%)
#   adding: Tensorflow/models/research/deeplab/core/conv2d_ws_test.py (deflated 86%)
#   adding: Tensorflow/models/research/deeplab/core/dense_prediction_cell_test.py (deflated 75%)
#   adding: Tensorflow/models/research/deeplab/core/__init__.py (stored 0%)
#   adding: Tensorflow/models/research/deeplab/core/resnet_v1_beta_test.py (deflated 88%)
#   adding: Tensorflow/models/research/deeplab/core/conv2d_ws.py (deflated 70%)
#   adding: Tensorflow/models/research/deeplab/core/utils_test.py (deflated 69%)
#   adding: Tensorflow/models/research/deeplab/core/nas_cell.py (deflated 70%)
#   adding: Tensorflow/models/research/deeplab/core/dense_prediction_cell_branch5_top1_cityscapes.json (deflated 71%)
#   adding: Tensorflow/models/research/deeplab/core/nas_network_test.py (deflated 62%)
#   adding: Tensorflow/models/research/deeplab/core/xception.py (deflated 81%)
#   adding: Tensorflow/models/research/deeplab/core/resnet_v1_beta.py (deflated 85%)
#   adding: Tensorflow/models/research/deeplab/core/xception_test.py (deflated 84%)
#   adding: Tensorflow/models/research/deeplab/core/preprocess_utils.py (deflated 71%)
#   adding: Tensorflow/models/research/deeplab/core/utils.py (deflated 67%)
#   adding: Tensorflow/models/research/deeplab/core/nas_genotypes.py (deflated 54%)
#   adding: Tensorflow/models/research/deeplab/convert_to_tflite.py (deflated 60%)
#   adding: Tensorflow/models/research/deeplab/train.py (deflated 70%)
#   adding: Tensorflow/models/research/deeplab/evaluation/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/g3doc/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/g3doc/img/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/g3doc/img/equation_pc.png (deflated 8%)
#   adding: Tensorflow/models/research/deeplab/evaluation/g3doc/img/equation_pq.png (deflated 5%)
#   adding: Tensorflow/models/research/deeplab/evaluation/parsing_covering.py (deflated 68%)
#   adding: Tensorflow/models/research/deeplab/evaluation/base_metric.py (deflated 66%)
#   adding: Tensorflow/models/research/deeplab/evaluation/test_utils.py (deflated 62%)
#   adding: Tensorflow/models/research/deeplab/evaluation/streaming_metrics_test.py (deflated 86%)
#   adding: Tensorflow/models/research/deeplab/evaluation/__init__.py (stored 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/eval_coco_format_test.py (deflated 78%)
#   adding: Tensorflow/models/research/deeplab/evaluation/streaming_metrics.py (deflated 77%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/bird_pred_instance.png (deflated 1%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/cat_pred_class.png (deflated 18%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/team_pred_class.png (deflated 8%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_gt.json (deflated 82%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/bird_gt.png (stored 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/cat_gt.png (deflated 9%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/cat_pred_instance.png (deflated 12%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/team_gt_instance.png (deflated 1%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/README.md (deflated 48%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_pred/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_pred/cat.png (deflated 2%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_pred/bird.png (deflated 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_pred/congress.png (deflated 12%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_pred/team.png (deflated 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/team_pred_instance.png (deflated 2%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/bird_pred_class.png (deflated 1%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_pred.json (deflated 82%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_gt/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_gt/cat.png (deflated 1%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_gt/bird.png (deflated 1%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_gt/congress.png (deflated 6%)
#   adding: Tensorflow/models/research/deeplab/evaluation/testdata/coco_gt/team.png (stored 0%)
#   adding: Tensorflow/models/research/deeplab/evaluation/README.md (deflated 64%)
#   adding: Tensorflow/models/research/deeplab/evaluation/panoptic_quality.py (deflated 70%)
#   adding: Tensorflow/models/research/deeplab/evaluation/panoptic_quality_test.py (deflated 82%)
#   adding: Tensorflow/models/research/deeplab/evaluation/test_utils_test.py (deflated 62%)
#   adding: Tensorflow/models/research/deeplab/evaluation/parsing_covering_test.py (deflated 73%)
#   adding: Tensorflow/models/research/deeplab/evaluation/eval_coco_format.py (deflated 70%)
#   adding: Tensorflow/models/research/deeplab/__init__.py (stored 0%)
#   adding: Tensorflow/models/research/deeplab/local_test_mobilenetv2.sh (deflated 61%)
#   adding: Tensorflow/models/research/deeplab/eval.py (deflated 67%)
#   adding: Tensorflow/models/research/deeplab/export_model.py (deflated 65%)
#   adding: Tensorflow/models/research/deeplab/README.md (deflated 62%)
#   adding: Tensorflow/models/research/deeplab/input_preprocess.py (deflated 68%)
#   adding: Tensorflow/models/research/deeplab/local_test.sh (deflated 64%)
#   adding: Tensorflow/models/research/deeplab/deprecated/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/deprecated/__init__.py (stored 0%)
#   adding: Tensorflow/models/research/deeplab/deprecated/segmentation_dataset.py (deflated 63%)
#   adding: Tensorflow/models/research/deeplab/deeplab_demo.ipynb (deflated 70%)
#   adding: Tensorflow/models/research/deeplab/model_test.py (deflated 69%)
#   adding: Tensorflow/models/research/deeplab/common_test.py (deflated 64%)
#   adding: Tensorflow/models/research/deeplab/vis.py (deflated 68%)
#   adding: Tensorflow/models/research/deeplab/utils/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/utils/get_dataset_colormap.py (deflated 72%)
#   adding: Tensorflow/models/research/deeplab/utils/save_annotation.py (deflated 58%)
#   adding: Tensorflow/models/research/deeplab/utils/get_dataset_colormap_test.py (deflated 69%)
#   adding: Tensorflow/models/research/deeplab/utils/__init__.py (stored 0%)
#   adding: Tensorflow/models/research/deeplab/utils/train_utils.py (deflated 71%)
#   adding: Tensorflow/models/research/deeplab/datasets/ (stored 0%)
#   adding: Tensorflow/models/research/deeplab/datasets/download_and_convert_ade20k.sh (deflated 56%)
#   adding: Tensorflow/models/research/deeplab/datasets/build_ade20k_data.py (deflated 62%)
#   adding: Tensorflow/models/research/deeplab/datasets/remove_gt_colormap.py (deflated 61%)
#   adding: Tensorflow/models/research/deeplab/datasets/download_and_convert_voc2012.sh (deflated 56%)
#   adding: Tensorflow/models/research/deeplab/datasets/build_data.py (deflated 66%)
#   adding: Tensorflow/models/research/deeplab/datasets/convert_cityscapes.sh (deflated 52%)
#   adding: Tensorflow/models/research/deeplab/datasets/data_generator_test.py (deflated 59%)
#   adding: Tensorflow/models/research/deeplab/datasets/__init__.py (stored 0%)
#   adding: Tensorflow/models/research/deeplab/datasets/build_voc2012_data.py (deflated 63%)
#   adding: Tensorflow/models/research/deeplab/datasets/build_cityscapes_data.py (deflated 62%)
#   adding: Tensorflow/models/research/deeplab/datasets/data_generator.py (deflated 67%)
#   adding: Tensorflow/models/research/autoaugment/ (stored 0%)
#   adding: Tensorflow/models/research/autoaugment/helper_utils.py (deflated 65%)
#   adding: Tensorflow/models/research/autoaugment/data_utils.py (deflated 68%)
#   adding: Tensorflow/models/research/autoaugment/custom_ops.py (deflated 66%)
#   adding: Tensorflow/models/research/autoaugment/shake_shake.py (deflated 64%)
#   adding: Tensorflow/models/research/autoaugment/train_cifar.py (deflated 70%)
#   adding: Tensorflow/models/research/autoaugment/README.md (deflated 57%)
#   adding: Tensorflow/models/research/autoaugment/policies.py (deflated 77%)
#   adding: Tensorflow/models/research/autoaugment/wrn.py (deflated 66%)
#   adding: Tensorflow/models/research/autoaugment/augmentation_transforms.py (deflated 71%)
#   adding: Tensorflow/models/research/autoaugment/shake_drop.py (deflated 68%)
#   adding: Tensorflow/models/research/rebar/ (stored 0%)
#   adding: Tensorflow/models/research/rebar/rebar_train.py (deflated 65%)
#   adding: Tensorflow/models/research/rebar/datasets.py (deflated 60%)
#   adding: Tensorflow/models/research/rebar/rebar.py (deflated 81%)
#   adding: Tensorflow/models/research/rebar/README.md (deflated 57%)
#   adding: Tensorflow/models/research/rebar/config.py (deflated 45%)
#   adding: Tensorflow/models/research/rebar/utils.py (deflated 57%)
#   adding: Tensorflow/models/research/rebar/logger.py (deflated 47%)
#   adding: Tensorflow/models/research/rebar/download_data.py (deflated 60%)
#   adding: Tensorflow/models/CODE_OF_CONDUCT.md (deflated 57%)
#   adding: Tensorflow/models/LICENSE (deflated 65%)
#   adding: Tensorflow/models/orbit/ (stored 0%)
#   adding: Tensorflow/models/orbit/examples/ (stored 0%)
#   adding: Tensorflow/models/orbit/examples/__init__.py (deflated 37%)
#   adding: Tensorflow/models/orbit/examples/single_task/ (stored 0%)
#   adding: Tensorflow/models/orbit/examples/single_task/single_task_trainer_test.py (deflated 52%)
#   adding: Tensorflow/models/orbit/examples/single_task/single_task_evaluator_test.py (deflated 55%)
#   adding: Tensorflow/models/orbit/examples/single_task/__init__.py (deflated 37%)
#   adding: Tensorflow/models/orbit/examples/single_task/single_task_evaluator.py (deflated 57%)
#   adding: Tensorflow/models/orbit/examples/single_task/single_task_trainer.py (deflated 61%)
#   adding: Tensorflow/models/orbit/standard_runner.py (deflated 74%)
#   adding: Tensorflow/models/orbit/controller_test.py (deflated 86%)
#   adding: Tensorflow/models/orbit/runner.py (deflated 60%)
#   adding: Tensorflow/models/orbit/__init__.py (deflated 53%)
#   adding: Tensorflow/models/orbit/README.md (deflated 40%)
#   adding: Tensorflow/models/orbit/LICENSE (deflated 65%)
#   adding: Tensorflow/models/orbit/actions/ (stored 0%)
#   adding: Tensorflow/models/orbit/actions/export_saved_model_test.py (deflated 79%)
#   adding: Tensorflow/models/orbit/actions/new_best_metric.py (deflated 66%)
#   adding: Tensorflow/models/orbit/actions/__init__.py (deflated 55%)
#   adding: Tensorflow/models/orbit/actions/export_saved_model.py (deflated 61%)
#   adding: Tensorflow/models/orbit/actions/new_best_metric_test.py (deflated 72%)
#   adding: Tensorflow/models/orbit/actions/conditional_action.py (deflated 52%)
#   adding: Tensorflow/models/orbit/actions/conditional_action_test.py (deflated 48%)
#   adding: Tensorflow/models/orbit/controller.py (deflated 71%)
#   adding: Tensorflow/models/orbit/standard_runner_test.py (deflated 72%)
#   adding: Tensorflow/models/orbit/utils/ (stored 0%)
#   adding: Tensorflow/models/orbit/utils/loop_fns.py (deflated 70%)
#   adding: Tensorflow/models/orbit/utils/common.py (deflated 58%)
#   adding: Tensorflow/models/orbit/utils/tpu_summaries_test.py (deflated 70%)
#   adding: Tensorflow/models/orbit/utils/epoch_helper.py (deflated 59%)
#   adding: Tensorflow/models/orbit/utils/tpu_summaries.py (deflated 63%)
#   adding: Tensorflow/models/orbit/utils/summary_manager.py (deflated 63%)
#   adding: Tensorflow/models/orbit/utils/__init__.py (deflated 51%)
#   adding: Tensorflow/models/orbit/utils/common_test.py (deflated 44%)
#   adding: Tensorflow/scripts/ (stored 0%)
#   adding: Tensorflow/scripts/generate_tfrecord.py (deflated 68%)
#   adding: Tensorflow/scripts/.git/ (stored 0%)
#   adding: Tensorflow/scripts/.git/objects/ (stored 0%)
#   adding: Tensorflow/scripts/.git/objects/07/ (stored 0%)
#   adding: Tensorflow/scripts/.git/objects/07/bf1b9178bb4e9e48ec2dae8ec89269a5c44e54 (stored 0%)
#   adding: Tensorflow/scripts/.git/objects/07/d3e8d86415fa96ac86ac3c72cf999eac96b74b (stored 0%)
#   adding: Tensorflow/scripts/.git/objects/info/ (stored 0%)
#   adding: Tensorflow/scripts/.git/objects/ca/ (stored 0%)
#   adding: Tensorflow/scripts/.git/objects/ca/ad456d8bd86613a9aa74ccb6e934862c8e584a (stored 0%)
#   adding: Tensorflow/scripts/.git/objects/pack/ (stored 0%)
#   adding: Tensorflow/scripts/.git/packed-refs (deflated 10%)
#   adding: Tensorflow/scripts/.git/hooks/ (stored 0%)
#   adding: Tensorflow/scripts/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: Tensorflow/scripts/.git/hooks/update.sample (deflated 68%)
#   adding: Tensorflow/scripts/.git/hooks/pre-commit.sample (deflated 43%)
#   adding: Tensorflow/scripts/.git/hooks/post-update.sample (deflated 27%)
#   adding: Tensorflow/scripts/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: Tensorflow/scripts/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: Tensorflow/scripts/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: Tensorflow/scripts/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
#   adding: Tensorflow/scripts/.git/hooks/pre-push.sample (deflated 50%)
#   adding: Tensorflow/scripts/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: Tensorflow/scripts/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: Tensorflow/scripts/.git/logs/ (stored 0%)
#   adding: Tensorflow/scripts/.git/logs/refs/ (stored 0%)
#   adding: Tensorflow/scripts/.git/logs/refs/remotes/ (stored 0%)
#   adding: Tensorflow/scripts/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: Tensorflow/scripts/.git/logs/refs/remotes/origin/HEAD (deflated 27%)
#   adding: Tensorflow/scripts/.git/logs/refs/heads/ (stored 0%)
#   adding: Tensorflow/scripts/.git/logs/refs/heads/main (deflated 27%)
#   adding: Tensorflow/scripts/.git/logs/HEAD (deflated 27%)
#   adding: Tensorflow/scripts/.git/index (deflated 10%)
#   adding: Tensorflow/scripts/.git/description (deflated 14%)
#   adding: Tensorflow/scripts/.git/refs/ (stored 0%)
#   adding: Tensorflow/scripts/.git/refs/tags/ (stored 0%)
#   adding: Tensorflow/scripts/.git/refs/remotes/ (stored 0%)
#   adding: Tensorflow/scripts/.git/refs/remotes/origin/ (stored 0%)
#   adding: Tensorflow/scripts/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: Tensorflow/scripts/.git/refs/heads/ (stored 0%)
#   adding: Tensorflow/scripts/.git/refs/heads/main (stored 0%)
#   adding: Tensorflow/scripts/.git/info/ (stored 0%)
#   adding: Tensorflow/scripts/.git/info/exclude (deflated 28%)
#   adding: Tensorflow/scripts/.git/branches/ (stored 0%)
#   adding: Tensorflow/scripts/.git/config (deflated 32%)
#   adding: Tensorflow/scripts/.git/HEAD (stored 0%)

# %%
# files.download("/content/Tensorflow.zip")
