# %%
from pprint import pprint
import base64
import json
import mimetypes
import os
import requests
import sys
import pandas as pd
from openai import OpenAI

# %% [markdown]
# # Prepare images to call gpt api

# %%
master_df = pd.read_csv("../../master_list.csv")
print(master_df.shape)
master_df.head()
# Out:
# (4454, 12)
#                                             filepath  xmin  ymin  xmax  ymax  \
# 0  IMG_20230428_123528_jpg.rf.5687b7b914f6d9aa98c...   151    42   497   591
# 1  IMG_20230428_123522_jpg.rf.204ff37f497f2dce442...    88    81   442   567
# 2  IMG_20230428_123708_jpg.rf.141ecd0cefaea75c0b7...    35    34   492   622
# 3  IMG_20230428_123521_jpg.rf.1069b402272252862ec...    99   122   428   587
# 4  IMG_20230428_123659_jpg.rf.5e1b6c4caabe48cf360...   103    17   474   592
#
#                                 label ProductType    Weight HalalStatus  \
# 0  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 1  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 2  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 3  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 4  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
#
#   HealthStatus  new_camera  tag
# 0   NonHealthy           0  NaN
# 1   NonHealthy           0  NaN
# 2   NonHealthy           0  NaN
# 3   NonHealthy           0  NaN
# 4   NonHealthy           0  NaN

# %%
prd_group_df = pd.read_csv("../product_group.csv")
prd_group_df['group'] = prd_group_df['group'].astype('Int64')
prd_group_df = prd_group_df.loc[prd_group_df['tag'] != "test",]
prd_group_df.head()
# Out:
#                                             filepath  \
# 0  IMG_20230428_123528_jpg.rf.5687b7b914f6d9aa98c...
# 1  IMG_20230428_123522_jpg.rf.204ff37f497f2dce442...
# 2  IMG_20230428_123708_jpg.rf.141ecd0cefaea75c0b7...
# 3  IMG_20230428_123521_jpg.rf.1069b402272252862ec...
# 4  IMG_20230428_123659_jpg.rf.5e1b6c4caabe48cf360...
#
#                                 label ProductType    Weight HalalStatus  \
# 0  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 1  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 2  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 3  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 4  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
#
#   HealthStatus  new_camera  tag  group
# 0   NonHealthy           0  NaN      1
# 1   NonHealthy           0  NaN      1
# 2   NonHealthy           0  NaN      2
# 3   NonHealthy           0  NaN      1
# 4   NonHealthy           0  NaN      2

# %%
total_df = pd.merge(master_df, prd_group_df[['filepath','group']], on='filepath', how='left')
total_df = total_df.dropna(subset=['group'])
total_df = total_df.reset_index(drop=True)
print(total_df.shape)
total_df.head()
# Out:
# (2947, 13)
#                                             filepath  xmin  ymin  xmax  ymax  \
# 0  IMG_20230428_123528_jpg.rf.5687b7b914f6d9aa98c...   151    42   497   591
# 1  IMG_20230428_123522_jpg.rf.204ff37f497f2dce442...    88    81   442   567
# 2  IMG_20230428_123708_jpg.rf.141ecd0cefaea75c0b7...    35    34   492   622
# 3  IMG_20230428_123521_jpg.rf.1069b402272252862ec...    99   122   428   587
# 4  IMG_20230428_123659_jpg.rf.5e1b6c4caabe48cf360...   103    17   474   592
#
#                                 label ProductType    Weight HalalStatus  \
# 0  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 1  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 2  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 3  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
# 4  Sugar_400-499g_NonHalal_NonHealthy       Sugar  400-499g    NonHalal
#
#   HealthStatus  new_camera  tag  group
# 0   NonHealthy           0  NaN      1
# 1   NonHealthy           0  NaN      1
# 2   NonHealthy           0  NaN      2
# 3   NonHealthy           0  NaN      1
# 4   NonHealthy           0  NaN      2

# %%
result_df = total_df.groupby(['label', 'group'])['filepath'].first().reset_index()
print(result_df.shape)
result_df.head()
# Out:
# (351, 3)
#                                    label  group  \
# 0       AdultMilk_1-99g_Halal_NonHealthy      1
# 1       AdultMilk_1-99g_Halal_NonHealthy      2
# 2       AdultMilk_1-99g_Halal_NonHealthy      3
# 3  AdultMilk_1000-1999g_Halal_NonHealthy      1
# 4  AdultMilk_1000-1999g_Halal_NonHealthy      2
#
#                          filepath
# 0  2023_10_25_11_23_10_398347.jpg
# 1  2023_10_25_11_29_12_163138.jpg
# 2  2023_10_25_11_30_13_941552.jpg
# 3  2023_10_25_11_18_17_414290.jpg
# 4  2023_10_25_11_24_30_751596.jpg

# %%
result_df.to_csv("test.csv")

# %%
total_df['ProductType'].unique()
# Out:
# array(['Sugar', 'OtherNoodles', 'Oil', 'BiscuitsCrackersCookies', 'Nuts',
#        'HoneyOtherSpreads', 'BeehoonVermicelli', 'MiloPowder',
#        'RolledOatsInstantOatmeal', 'OtherSauceDressing',
#        'SweetsChocolatesOthers', 'BreakfastCereals', 'Coffee',
#        'InstantNoodles', 'CerealBeveragePowder', 'OtherBakingNeeds',
#        'BabyMilkPowder', 'MaternalMilkPowder', 'TeaPowderLeaves', 'Pasta',
#        'FlavoredMilk', 'Sardines', 'Flour', 'Babyfood', 'Potatochips',
#        'Salt', 'Peanutbutter', 'ChilliSauce', 'NutellaChocolate',
#        'InstantMeals', 'Kaya', 'AdultMilk', 'CannedPacketCreamersSweet',
#        'CornChip', 'SoftDrinks', 'OtherDriedFood', 'FruitJuice',
#        'CannedBakedBeans', 'CannedBeefOtherMeats', 'CannedBraisedPeanuts',
#        'CannedChicken', 'CannedFruitsCocktail', 'CannedMashrooms',
#        'CannedPickles', 'CannedPorkLunchronMeat', 'CannedSardingMackerel',
#        'CannedSoup', 'CannedTunaDace', 'CannedVegetarianFood',
#        'ChocolateMaltPowder', 'CoffeePowder', 'CookingCreamMilk',
#        'CurryPastePowderSauce', 'DarkSoySauce', 'DriedBeans', 'DriedFood',
#        'DriedFruits', 'DriedMeatSeafood', 'DriedVegetables',
#        'HeabsSpicesPepper', 'Jam', 'KetchupChillSauce', 'LightSoySauce',
#        'MilkDrink', 'MilkPowder', 'OtherCannedBeansPeasPeanuts',
#        'OtherCannedSeafood', 'OtherCannedVegetables', 'OtherHotBeverages',
#        'OtherSpreads', 'PastaSauce', 'SoftDrinksOtherReadyToDrink',
#        'SoupStock', 'TeaDrink'], dtype=object)

# %%
total_df['Weight'].unique()
# Out:
# array(['400-499g', '700-799g', '500-599g', '200-299g', '100-199g',
#        '1-99g', '300-399g', '600-699g', '800-899g', '1000-1999g',
#        '900-999g', '3000-3999g'], dtype=object)

# %%
total_df['HalalStatus'].unique()
# Out:
# array(['NonHalal', 'Halal'], dtype=object)

# %%
total_df['HealthStatus'].unique()
# Out:
# array(['NonHealthy', 'Healthy'], dtype=object)

# %% [markdown]
# # Call gpt to recognize product, weight, halal and health

# %%
import base64

def encode_image(image_path):
    """Encodes an image to Base64."""
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# %%
with open('/Users/liupeng/Desktop/Research/api.txt', 'r') as file:
    api_key = file.read()

# %%
existing_paths = []

# %%
total_df.shape
# Out:
# (2947, 13)

# %%
result_df.shape
# Out:
# (351, 3)

# %%
# # adhoc: prepare images not called yet
# test_df = pd.read_csv("existing_api_calls.csv")
# existing_api_paths = test_df['filepath']
# existing_api_paths_set = set(existing_api_paths)
# pending_api_paths = [i for i in result_df['filepath'].tolist() if i not in existing_api_paths_set]
# len(pending_api_paths)

# %%
# # image_paths = result_df['filepath']
# image_paths = pending_api_paths
# new_paths = [i fo r i in image_paths if i not in existing_paths]
# len(new_paths)

# %%
new_paths = result_df['filepath']
len(new_paths)
# Out:
# 351

# %%
# Placeholder for the parsed data
parsed_data = []
tmp_paths = []
# Iterate over each image path
for tmp_img_path in new_paths[306:]:
    tmp_paths.append(tmp_img_path)
    # if tmp_img_path != new_paths[0]:
    #     break
    image_path = os.path.join("../../../rshiny/www/all_images/", tmp_img_path)
    base64_image = encode_image(image_path)
    
    headers = {
          "Content-Type": "application/json",
          "Authorization": f"Bearer {api_key}"
        }

    payload = {
              "model": "gpt-4-vision-preview",
              "messages": [
                {
                  "role": "user",
                  "content": [
                    {
                      "type": "text",
                      "text": """ 
                      For this image, can you a prediction for the following four labels? 
                      The product type is based on the appearance of the product, 
                      the weight is to recognize how heavy the product is by identify the weight information on the appearance,
                      the halal status is to recognize if the product is halal food or not, 
                      and the healthy status is to recognize if the product is healthy if it contains a read triangle shape based on Singapore standard.
                      Note that you can only choose one from the given options in the bracket for each label, even if you are not sure. 
                      also there is no need to add an extra note to your answer.
                        product type (
                            'Sugar', 'OtherNoodles', 'Oil', 'BiscuitsCrackersCookies', 'Nuts',
                           'HoneyOtherSpreads', 'BeehoonVermicelli', 'MiloPowder',
                           'RolledOatsInstantOatmeal', 'OtherSauceDressing',
                           'SweetsChocolatesOthers', 'BreakfastCereals', 'Coffee',
                           'InstantNoodles', 'CerealBeveragePowder', 'OtherBakingNeeds',
                           'BabyMilkPowder', 'MaternalMilkPowder', 'TeaPowderLeaves', 'Pasta',
                           'FlavoredMilk', 'Sardines', 'Flour', 'Babyfood', 'Potatochips',
                           'Salt', 'Peanutbutter', 'ChilliSauce', 'NutellaChocolate',
                           'InstantMeals', 'Kaya', 'AdultMilk', 'CannedPacketCreamersSweet',
                           'CornChip', 'SoftDrinks', 'OtherDriedFood', 'FruitJuice',
                           'CannedBakedBeans', 'CannedBeefOtherMeats', 'CannedBraisedPeanuts',
                           'CannedChicken', 'CannedFruitsCocktail', 'CannedMashrooms',
                           'CannedPickles', 'CannedPorkLunchronMeat', 'CannedSardingMackerel',
                           'CannedSoup', 'CannedTunaDace', 'CannedVegetarianFood',
                           'ChocolateMaltPowder', 'CoffeePowder', 'CookingCreamMilk',
                           'CurryPastePowderSauce', 'DarkSoySauce', 'DriedBeans', 'DriedFood',
                           'DriedFruits', 'DriedMeatSeafood', 'DriedVegetables',
                           'HeabsSpicesPepper', 'Jam', 'KetchupChillSauce', 'LightSoySauce',
                           'MilkDrink', 'MilkPowder', 'OtherCannedBeansPeasPeanuts',
                           'OtherCannedSeafood', 'OtherCannedVegetables', 'OtherHotBeverages',
                           'OtherSpreads', 'PastaSauce', 'SoftDrinksOtherReadyToDrink',
                           'SoupStock', 'TeaDrink'
                        ),
                        weight ('400-499g', '700-799g', '500-599g', '200-299g', '100-199g',
                           '1-99g', '300-399g', '600-699g', '800-899g', '1000-1999g',
                           '900-999g', '3000-3999g'
                        ),
                        halal status ('NonHalal', 'Halal'),
                        healthy status ('NonHealthy', 'Healthy'),
                        
                        Also, provide the following assessment
                        image reflection (High, Medium, Low)
                        image clarity (High, Medium, Low)
                        prediction confidence for the product type (High, Medium, Low)
                        prediction confidence for the weight (High, Medium, Low)
                        prediction confidence for the halal status (High, Medium, Low)
                        prediction confidence for the healthy status (High, Medium, Low)

                        format your answer in json format so that it could be easily converted to dataframe
                        """
                    },
                    {
                      "type": "image_url",
                      "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}"
                      }
                    }
                  ]
                }
              ],
              "max_tokens": 300
            }


    response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
    content = response.json()['choices'][0]['message']['content']

    response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

    # Extracting the message content (the table with predictions)
    content = response.json()['choices'][0]['message']['content']

    # Parsing the content to extract prediction values
    # Splitting the content string into lines and then parsing each line
    lines = content.strip().split('\n')[2:]  # Skipping the header

    # Parsing the strings to extract the relevant information
    data_parsed = [line.replace('"', '').strip() for line in lines if ':' in line]
    data_dict = {item.split(":")[0].strip(): item.split(":")[1].strip().strip(',') for item in data_parsed}

    # Converting the dictionary into a DataFrame
    df_from_strings = pd.DataFrame([data_dict])

    parsed_data.append(df_from_strings)

# %%
len(parsed_data)
# Out:
# 45

# %%
# response

# %%
col_names = ['product_type', 'weight', 'halal', 'health', 'image_reflection', 
                  'image_clarity', 'product_type_confidence', 'weight_confidence',
                  'halal_confidence', 'health_confidence']

# Normalizing column names for consistency across all DataFrames
normalized_dfs = []
tmp_valid_paths = []

# for df in parsed_data:
for i in range(len(parsed_data)):
    df = parsed_data[i]
    if df.shape[1] != 0:
        if df.shape[1] != 10:
            print("--\n")
            print(i)
            print(df.shape[1])
            if df.columns[-1]=="Note":
                df.drop(columns=['Note'], inplace=True)
                df.columns = col_names
                normalized_dfs.append(df)
                tmp_valid_paths.append(tmp_paths[i])
            elif df.shape[1] == 11:
                df = df.iloc[:,:-1]
                df.columns = col_names
                normalized_dfs.append(df)
                tmp_valid_paths.append(tmp_paths[i])
        else:
            # Renaming columns to have consistent names across all DataFrames
            df.columns = col_names
            normalized_dfs.append(df)
            tmp_valid_paths.append(tmp_paths[i])


# Combining all DataFrames into a single DataFrame
combined_df = pd.concat(normalized_dfs, ignore_index=True)

# Add img filename
combined_df['img_filename'] = tmp_valid_paths
cols = combined_df.columns.tolist()
cols = cols[-1:] + cols[:-1]  # Move the last column to the first position
combined_df = combined_df[cols] 

combined_df
# Out:
#                                          img_filename  \
# 0   IMG_9750_JPG.rf.9409a88b8cbde9797930051f7d9c89...
# 1   2023_8_11_11_58_23_422340_png.rf.7cb6b8c59f31a...
# 2   IMG_9746_JPG.rf.5fea5bf82d593778aa52b30dd6e297...
# 3   IMG_9740_JPG.rf.1b074db5f88ee6fa0f70f4b58e959b...
# 4   IMG_9728_JPG.rf.06448f86fe4b09df664962ac504314...
# 5   IMG_9725_JPG.rf.264aa5f74ecfcb452c586df78e05bb...
# 6   IMG_9686_JPG.rf.18812431e069e1830d4a937eca2c4e...
# 7   IMG_9695_JPG.rf.512683f7e7452c26716acf81620ce7...
# 8                                 20240123_2_0668.jpg
# 9   IMG_20230428_124248_1_jpg.rf.4bc4ccec17bb3485c...
# 10  IMG_20230428_124153_jpg.rf.4c60c2d88bb830afc0e...
# 11                                  20231222_0571.jpg
# 12  IMG_20230428_124009_jpg.rf.1d505673eb6cae9cb1b...
# 13  IMG_20230428_123849_jpg.rf.0f508aa8ac3dcc1f136...
# 14  Sardines_100-199g_0311_Halal_5_png.rf.578c1231...
# 15  Sardines_100-199g_0311_NonHalal_12_png.rf.11f0...
# 16  Sardines_100-199g_0311_NonHalal_8_png.rf.14257...
# 17  Sardines_400-499g_0311_Halal_5_png.rf.0dfb0015...
# 18  Sardines_400-499g_0311_Halal_10_png.rf.1806a4a...
# 19  Sardines_400-499g_0311_Halal_15_png.rf.8295f19...
# 20                                20240123_2_2113.jpg
# 21                                  20231222_0710.jpg
# 22                                20240123_2_0859.jpg
# 23  2023_8_11_12_19_36_947407_png.rf.3d8c972543d03...
# 24                                20240123_2_0545.jpg
# 25  IMG_20230428_121701_jpg.rf.164e991fa8daba99a4e...
# 26  IMG_20230428_121505_jpg.rf.26a35bd752b0bcccfc5...
# 27  IMG_20230428_123420_jpg.rf.017b995f929c5b891bd...
# 28  IMG_20230428_123316_1_jpg.rf.86d6a0d85cb527084...
# 29  IMG_20230428_123528_jpg.rf.5687b7b914f6d9aa98c...
# 30  IMG_20230428_123708_jpg.rf.141ecd0cefaea75c0b7...
# 31  IMG_20230428_123156_jpg.rf.05380fd58804a70a410...
# 32                              output_frame_0567.png
# 33                      WIN_20231207_11_29_19_Pro.jpg
# 34                                  20231222_0439.jpg
# 35                                  20231222_0548.jpg
# 36                                20240123_4_0956.jpg
# 37                                20240123_4_0137.jpg
# 38                                20240123_4_0010.jpg
# 39  IMG_2133_jpeg.rf.27e58972dde01ae0130a3933b0ce9...
# 40                                20240123_2_2969.jpg
# 41  2023_8_11_12_10_59_359634_png.rf.50c4156c6cfd3...
# 42  IMG_2153_jpeg.rf.1803fdfd61b12ea4894b815f7702e...
# 43  IMG_2147_jpeg.rf.713a8ffd7d24b1fc6d76c8745bef4...
# 44                                20240123_2_1079.jpg
#
#                 product_type                         weight  \
# 0   RolledOatsInstantOatmeal                       500-599g
# 1   RolledOatsInstantOatmeal                       400-499g
# 2   RolledOatsInstantOatmeal                       500-599g
# 3   RolledOatsInstantOatmeal                       500-599g
# 4   RolledOatsInstantOatmeal                       800-899g
# 5   RolledOatsInstantOatmeal                       800-899g
# 6   RolledOatsInstantOatmeal                       100-199g
# 7   RolledOatsInstantOatmeal                       800-899g
# 8                       Salt                       300-399g
# 9                       Salt                       900-999g
# 10                      Salt                       500-599g
# 11                      Salt                       300-399g
# 12                      Salt                          1-99g
# 13                      Salt                       500-599g
# 14     CannedSardingMackerel                       100-199g
# 15            CannedSardines                       400-499g
# 16            CannedSardines                       100-199g
# 17            CannedSardines                       300-399g
# 18     CannedSardingMackerel                       400-499g
# 19     CannedSardingMackerel                       400-499g
# 20                MiloPowder                       300-399g
# 21                FruitJuice                       300-399g
# 22              OtherNoodles                          1-99g
# 23                     Sugar  No weight information visible
# 24                     Sugar                       500-599g
# 25                      Salt                       500-599g
# 26                     Sugar                     2000-2999g
# 27                     Sugar                     1000-1999g
# 28                     Sugar                          1-99g
# 29                     Sugar                       500-599g
# 30                     Sugar                       300-399g
# 31                     Sugar                          1-99g
# 32           TeaPowderLeaves                       100-199g
# 33    SweetsChocolatesOthers                       100-199g
# 34   BiscuitsCrackersCookies                       100-199g
# 35   BiscuitsCrackersCookies                       100-199g
# 36          OtherBakingNeeds                       400-499g
# 37    SweetsChocolatesOthers                       300-399g
# 38   BiscuitsCrackersCookies                       400-499g
# 39    SweetsChocolatesOthers                       500-599g
# 40    SweetsChocolatesOthers                       100-199g
# 41           TeaPowderLeaves                       100-199g
# 42           TeaPowderLeaves                       200-299g
# 43                     Pasta                       400-499g
# 44    SweetsChocolatesOthers                       100-199g
#
#                            halal                         health  \
# 0                          Halal                        Healthy
# 1                          Halal                        Healthy
# 2                          Halal                        Healthy
# 3                          Halal                        Healthy
# 4                          Halal                        Healthy
# 5                          Halal                        Healthy
# 6                          Halal                        Healthy
# 7                          Halal                        Healthy
# 8                          Halal                     NonHealthy
# 9                          Halal                     NonHealthy
# 10                         Halal                     NonHealthy
# 11                         Halal                     NonHealthy
# 12                         Halal                     NonHealthy
# 13                         Halal                     NonHealthy
# 14                         Halal                     NonHealthy
# 15                         Halal                     NonHealthy
# 16                      NonHalal                     NonHealthy
# 17                         Halal                     NonHealthy
# 18                         Halal                     NonHealthy
# 19                         Halal                     NonHealthy
# 20                         Halal                     NonHealthy
# 21                         Halal                     NonHealthy
# 22                         Halal                     NonHealthy
# 23  No halal information visible  No health information visible
# 24                         Halal                     NonHealthy
# 25                         Halal                     NonHealthy
# 26                         Halal                     NonHealthy
# 27                         Halal                     NonHealthy
# 28                         Halal                     NonHealthy
# 29                         Halal                     NonHealthy
# 30                         Halal                     NonHealthy
# 31                         Halal                     NonHealthy
# 32                         Halal                        Healthy
# 33                      NonHalal                     NonHealthy
# 34                         Halal                     NonHealthy
# 35                         Halal                     NonHealthy
# 36                         Halal                     NonHealthy
# 37                         Halal                     NonHealthy
# 38                         Halal                     NonHealthy
# 39                         Halal                     NonHealthy
# 40                         Halal                     NonHealthy
# 41                         Halal                        Healthy
# 42                         Halal                     NonHealthy
# 43                         Halal                     NonHealthy
# 44                         Halal                     NonHealthy
#
#    image_reflection image_clarity product_type_confidence weight_confidence  \
# 0               Low          High                    High              High
# 1               Low        Medium                    High            Medium
# 2            Medium          High                    High              High
# 3               Low          High                    High              High
# 4            Medium          High                    High            Medium
# 5               Low          High                    High              High
# 6               Low          High                    High              High
# 7               Low          High                    High            Medium
# 8               Low          High                    High            Medium
# 9            Medium          High                    High              High
# 10              Low          High                    High              High
# 11              Low        Medium                    High               Low
# 12              Low          High                    High               Low
# 13              Low          High                    High              High
# 14              Low          High                    High              High
# 15           Medium        Medium                    High              High
# 16              Low          High                    High            Medium
# 17           Medium          High                    High              High
# 18              Low          High                    High            Medium
# 19              Low          High                    High              High
# 20              Low          High                    High            Medium
# 21              Low        Medium                    High            Medium
# 22              Low           Low                    High               Low
# 23              Low           Low                  Medium               Low
# 24           Medium          High                    High              High
# 25              Low           Low                     Low               Low
# 26              Low        Medium                    High              High
# 27              Low          High                    High              High
# 28              Low          High                    High            Medium
# 29           Medium          High                    High              High
# 30              Low          High                    High              High
# 31           Medium           Low                     Low               Low
# 32           Medium        Medium                    High               Low
# 33              Low        Medium                    High               Low
# 34           Medium        Medium                    High               Low
# 35              Low          High                    High            Medium
# 36           Medium          High                     Low               Low
# 37           Medium          High                    High              High
# 38           Medium          High                    High            Medium
# 39              Low          High                    High              High
# 40           Medium        Medium                  Medium               Low
# 41              Low           Low                  Medium               Low
# 42              Low          High                    High            Medium
# 43              Low          High                  Medium              High
# 44              Low          High                  Medium            Medium
#
#    halal_confidence health_confidence
# 0            Medium            Medium
# 1            Medium            Medium
# 2               Low            Medium
# 3               Low            Medium
# 4               Low            Medium
# 5              High            Medium
# 6            Medium            Medium
# 7              High              High
# 8               Low               Low
# 9               Low              High
# 10              Low              High
# 11              Low              High
# 12           Medium            Medium
# 13              Low               Low
# 14              Low               Low
# 15           Medium               Low
# 16              Low               Low
# 17           Medium               Low
# 18             High            Medium
# 19           Medium               Low
# 20             High            Medium
# 21           Medium            Medium
# 22           Medium               Low
# 23              Low               Low
# 24              Low            Medium
# 25              Low               Low
# 26              Low               Low
# 27           Medium              High
# 28              Low              High
# 29           Medium              High
# 30           Medium            Medium
# 31              Low               Low
# 32           Medium            Medium
# 33              Low               Low
# 34           Medium              High
# 35              Low               Low
# 36              Low               Low
# 37           Medium               Low
# 38              Low            Medium
# 39              Low            Medium
# 40              Low            Medium
# 41              Low               Low
# 42             High            Medium
# 43           Medium               Low
# 44              Low              High

# %%
parsed_data[45]
# Out:
#   product_type  weight halal_status healthy_status image_reflection  \
# 0         High  Medium          Low            Low              Low
#
#   image_clarity prediction_confidence
# 0        Medium                     {

# %%
combined_df.to_csv("GPT_model/current_prediction/gpt_rst_305-350.csv")

# %%
305+45
# Out:
# 350

# %% [markdown]
# # Combine all gpt predictions

# %%
import pandas as pd
import glob

# %%
path = 'GPT_model/current_prediction' # Update this to your folder's path
all_files = glob.glob(path + "/*.csv")
all_files
# Out:
# ['GPT_model/current_prediction/gpt_rst_305-350.csv',
#  'GPT_model/current_prediction/gpt_rst_129-305.csv',
#  'GPT_model/current_prediction/gpt_rst_60-80.csv',
#  'GPT_model/current_prediction/gpt_rst_48-59.csv',
#  'GPT_model/current_prediction/gpt_rst_0-47.csv',
#  'GPT_model/current_prediction/gpt_rst_81-128.csv']

# %%
all_dataframes = [] # A list to store each dataframe

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    all_dataframes.append(df)

combined_df2 = pd.concat(all_dataframes, axis=0, ignore_index=True)

# %%
final_df = combined_df2.drop_duplicates()
final_df = final_df.iloc[:,1:]
final_df.head()
# Out:
#                                         img_filename  \
# 0  IMG_9750_JPG.rf.9409a88b8cbde9797930051f7d9c89...
# 1  2023_8_11_11_58_23_422340_png.rf.7cb6b8c59f31a...
# 2  IMG_9746_JPG.rf.5fea5bf82d593778aa52b30dd6e297...
# 3  IMG_9740_JPG.rf.1b074db5f88ee6fa0f70f4b58e959b...
# 4  IMG_9728_JPG.rf.06448f86fe4b09df664962ac504314...
#
#                product_type    weight  halal   health image_reflection  \
# 0  RolledOatsInstantOatmeal  500-599g  Halal  Healthy              Low
# 1  RolledOatsInstantOatmeal  400-499g  Halal  Healthy              Low
# 2  RolledOatsInstantOatmeal  500-599g  Halal  Healthy           Medium
# 3  RolledOatsInstantOatmeal  500-599g  Halal  Healthy              Low
# 4  RolledOatsInstantOatmeal  800-899g  Halal  Healthy           Medium
#
#   image_clarity product_type_confidence weight_confidence halal_confidence  \
# 0          High                    High              High           Medium
# 1        Medium                    High            Medium           Medium
# 2          High                    High              High              Low
# 3          High                    High              High              Low
# 4          High                    High            Medium              Low
#
#   health_confidence
# 0            Medium
# 1            Medium
# 2            Medium
# 3            Medium
# 4            Medium

# %%
final_df.shape
# Out:
# (346, 11)

# %%
final_df.to_csv("GPT_model/chatgpt_prediction_v2.csv")
